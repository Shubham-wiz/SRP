# %%
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
from matplotlib import pyplot as plt
import datetime as dt
from torch.utils.data.dataloader import DataLoader
from datetime import datetime
from dataset.electricity_dataset import electricity_pre
from pandas import read_csv
import pandas
from datetime import datetime
import os
from matplotlib import pyplot
import warnings
from pandas import read_csv, DataFrame
import os
import torch
from pandas import read_csv
from datetime import datetime
import os
from matplotlib import pyplot
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import LabelEncoder
from torch.utils.data.dataset import Dataset
from torch.utils.data.dataloader import DataLoader
from torch.utils.data.sampler import Sampler, SubsetRandomSampler
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
gc =0

# %%
import random
np.set_printoptions(precision=4)
#array_=np.random.random_sample((365,2))
array_ = np.sin((np.arange(365)/10+3*np.random.random_sample(2).reshape(-1,1)).T)+np.random.random_sample((365,2))
array_1 = np.sin((np.arange(365)/10+2*np.random.random_sample(2).reshape(-1,1)).T)+np.random.random_sample((365,2))

# %%
fnl_=np.concatenate([array_,array_1, array_.sum(1)[:,None], array_1.sum(1)[:,None]], -1)

# %%
fnl_.shape
# Out:
# (365, 6)

# %%
start_date = dt.date(2021, 1, 1)
end_date   = dt.date(2022, 1, 1)
dates_ = [ start_date + dt.timedelta(n) for n in range(int ((end_date - start_date).days))]

# %%
dts=[]
for i in dates_ :
    dts.append(i.strftime("%Y-%m-%d"))

# %%
array_.shape
# Out:
# (365, 2)

# %%
#np.array(dts)

# %%
import pandas as pd

# %%
df = pd.DataFrame(fnl_)

# %%
df['date'] = pd.Series(np.array(dts), index=df.index)

# %%
df.set_index("date", inplace=True)

# %%
df[6] = df[4] +df[5]

# %%
df
# Out:
#                    0         1         2         3         4         5  \
# date
# 2021-01-01  0.783145  1.791637  1.232552  0.840484  2.574781  2.073036
# 2021-01-02  0.802525  1.878461  1.335720  1.294877  2.680986  2.630597
# 2021-01-03  0.822589  1.270161  1.374417  0.981885  2.092750  2.356302
# 2021-01-04  0.585755  1.379239  1.001110  1.104327  1.964994  2.105437
# 2021-01-05  0.297213  1.537773  1.766846  1.676470  1.834986  3.443316
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  0.896679  0.993697 -0.166995 -0.708858  1.890376 -0.875853
# 2021-12-28  1.327768  0.512467  0.555682 -0.143915  1.840235  0.411768
# 2021-12-29  1.356415  0.426705  0.427134 -0.565109  1.783120 -0.137975
# 2021-12-30  1.455753  1.077160  0.224730  0.245666  2.532913  0.470396
# 2021-12-31  1.891067  0.923843  0.898264  0.258435  2.814910  1.156700
#
#                    6
# date
# 2021-01-01  4.647817
# 2021-01-02  5.311583
# 2021-01-03  4.449052
# 2021-01-04  4.070431
# 2021-01-05  5.278302
# ...              ...
# 2021-12-27  1.014524
# 2021-12-28  2.252003
# 2021-12-29  1.645145
# 2021-12-30  3.003309
# 2021-12-31  3.971610
#
# [365 rows x 7 columns]

# %%
warnings.filterwarnings('ignore')
now = datetime.now()
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
GC=[]

# %%
hi=[

# %%
#  probabalistic model with likelihood function
class model(nn.Module):
    def __init__(self, num_lstms, input_dim, output_dim=1, hidden_dim=64):
        super(model, self).__init__()
        self.lstm_out = hidden_dim
        self.num_lstms = num_lstms
        lstms = []
        
        lstms.append(nn.LSTMCell(input_dim, self.lstm_out))
        for i in range(1, self.num_lstms):
            lstms.append(nn.LSTMCell(self.lstm_out, self.lstm_out))
        self.lstms = nn.ModuleList(lstms)
        # μ and σ  distibution -> next point for every t_i.prediction length is from output dimensions
        self.mean = nn.Linear(self.lstm_out, output_dim)
        self.std = nn.Linear(self.lstm_out, output_dim)

    def forward(self, input, covariates, future = 0):
        dev = input.device
        means = torch.Tensor().to(dev)
        stds = torch.Tensor().to(dev)
        outputs = []
        h_t = []
        c_t = []
        cond_ctx_len = input.size(1)
        pred_ctx_len = future
        #for covariartes concat input and covariates
        if covariates.shape[2] != 0:
            input = torch.cat((input, covariates[:, 0:cond_ctx_len, :]), 2)
        for i in range(0, self.num_lstms):
            h_t.append(torch.zeros(input.size(0), self.lstm_out, dtype=torch.float).to(dev))
            c_t.append(torch.zeros(input.size(0), self.lstm_out, dtype=torch.float).to(dev))
        '''
         h(hidden state),c(cell state)-> output of Lstm cell, h(i)-> passed to lstm(i+1) cell, 
         h(i) and c(i) are recurrent for lstm cell(i+1) 
         and the output from previous cell '''
        for i, input_t in enumerate(input.chunk(input.size(1), dim=1)):
            h_t[0], c_t[0] = self.lstms[0](input_t.squeeze(1), (h_t[0], c_t[0])) #first cell ->concat of input and covariates, recurrent input 
            for n in range(1, self.num_lstms):
                h_t[n], c_t[n] = self.lstms[n](h_t[n - 1], (h_t[n], c_t[n]))#susquent cells-> prev. output from stack, recurrent input
            mean = self.mean(h_t[n])
            std = self.std(h_t[n])
            means = torch.cat((means, mean.unsqueeze(1)), 1)
            stds = torch.cat((stds, std.unsqueeze(1)), 1)
        stds = self.softplus(stds)
        for i in range(future):
            output_t = torch.cat((mean, covariates[:, cond_ctx_len + i, :]), 1)
            h_t[0], c_t[0] = self.lstms[0](output_t, (h_t[0], c_t[0]))
            for n in range(1, self.num_lstms):
                h_t[n], c_t[n] = self.lstms[n](h_t[n - 1], (h_t[n], c_t[n]))
            mean = self.mean(h_t[n])
            std = self.std(h_t[n])
            std = self.softplus(std) # avoid infinties
            means = torch.cat((means, mean.unsqueeze(1)), 1)
            stds = torch.cat((stds, std.unsqueeze(1)), 1)
        means = means.unsqueeze(-1)
        stds = stds.unsqueeze(-1)
        outputs = torch.cat((means, stds), -1)
        return outputs

    def sample(self, mean, std):

        normal_dist = torch.distributions.normal.Normal(mean, std)
        return normal_dist.sample()

    def softplus(self, x):
        softplus = torch.log(1+torch.exp(x))
        softplus = torch.where(softplus==float('inf'), x, softplus)
        return softplus

    def NLL(self, outputs, truth):#negative log liklihood
        print(outputs.shape,truth.shape)
        mean, std = torch.split(outputs, 1, dim=3)
        #print('normal',mean.shape,std.shape)
        global gc
        #print(outputs,truth)
        print(gc)
        gc=gc+1
        print(f"{'NLL':.^20}")
        mean = mean.squeeze(3)
        std = std.squeeze(3)
        print('squeeze',mean.shape,std.shape)
        
        print(mean.shape,truth.shape)
        global GC   
        GC.append([mean,truth])
        diff = torch.sub(truth[:, :, :4], mean[:, :, :4])
        print(diff.shape)       
        
        loss = torch.mean(torch.div(torch.pow(diff, 2), torch.pow(std[:, :, :4], 2))) + 2*torch.mean(torch.log(std[:, :, :4])) + \
               torch.mean(torch.div(torch.pow(torch.sub(truth[:, :, 4:5],torch.sum(mean[:, :, 0:2], axis=2).reshape(mean[:, :,0:1].shape)), 2), torch.pow(std[:, :, 0:2], 2))) + 2*torch.mean(torch.log(std[:, :, 0:2])) + \
               torch.mean(torch.div(torch.pow(torch.sub(truth[:, :, 5:6],torch.sum(mean[:, :, 2:4], axis=2).reshape(mean[:, :,0:1].shape)), 2), torch.pow(std[:, :, 2:4], 2))) + 2*torch.mean(torch.log(std[:, :, 2:4])) + \
               torch.mean(torch.div(torch.pow(torch.sub(truth[:, :, 6:7],torch.sum(mean[:, :, 0:4], axis=2).reshape(mean[:, :,0:1].shape)), 2), torch.pow(std[:, :, :4], 2))) + 2*torch.mean(torch.log(std[:, :, :4]))

        #print('loss',loss.shape)
        return loss

# %%
def date_cv(x):
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

# %%
_params_ = {'lr': 0.01,
    'lr_step_size': 100,
    'lr_gamma': 1,
    'ctx_win_len': 80,
    'cond_win_len': 20,
    'batch_size': 32,
    'num_covariates': 0,
    'total_num_covariates': 0,
    'num_time_idx': 0,
    'num_targets': 7,
    'total_num_targets': 7,
    'num_lstms': 2,
    'hidden_dim': 64,
    'max_batches_per_epoch': 200,
    'num_epochs': 100,
    'data_file': 'test1.csv',
    'train_test_split': 0.7
}

ls_params = _params_
ls_params['num_covariates'] = 0

# %%
class utils:
    def __init__(self, dev,_params):
        self.min = 0
        self.max = 0
        self.range = 0
        self.mean = 0
        self.dev = dev
        self._params = _params

    def NRMSE(self, input, target):
        return np.sqrt(torch.nn.functional.mse_loss(input, target).item()) / torch.mean(torch.abs(target))

    def NormDeviation(self, input, target):
        return torch.mean(torch.abs(input - target)) / torch.mean(torch.abs(target))

    def MAE(self, input, target):
        return torch.mean(torch.abs(input - target))

    def split_batch(self, batch):
        num_time_idx = self._params['num_time_idx']
        num_targets = self._params['num_targets']
        total_num_targets = self._params['total_num_targets']
        num_covariates = self._params['num_covariates']    
        b = num_time_idx
        time_idx = batch[:, 1::, :b].to(self.dev).float()
        e = b + num_targets
        input = batch[:, 0:-1, b: e].to(self.dev).float()
        target = batch[:, 1::, b: e].to(self.dev).float()
        e = e - num_targets + total_num_targets
        total_num_covariates = batch.shape[2] - e + 1  
        covariates = time_idx
        b = e
        e = b + num_covariates
        if (num_covariates > 0):
            covariates = torch.cat((time_idx, batch[:, 1::, b: e]), -1)
        return input, target, covariates

    def scale(self, input, covariates):
        self.mean = torch.mean(input, dim=1).unsqueeze(1)
        input = input - self.mean
        min = torch.min(input, dim=1)[0].unsqueeze(1)
        max = torch.max(input, dim=1)[0].unsqueeze(1)
        self.range = max - min
        self.range[self.range < 1e-5] = 1e-5
        input = input / self.range

        num_covariates = self._params['num_covariates']
        if (num_covariates > 0):
            mean = torch.mean(covariates, dim=1).unsqueeze(1)
            covariates = covariates - mean
            min = torch.min(covariates, dim=1)[0].unsqueeze(1)
            max = torch.max(covariates, dim=1)[0].unsqueeze(1)
            range = max - min
            range[range < 1e-5] = 1e-5
            covariates = covariates / range
        return input, covariates

    def invert_scale(self, input, probabalistic=False):
        if probabalistic == False:
            return input * self.range + self.mean
        else:
            mean = input[:, :, :, 0]
            std = input[:, :, :, 1]
            scaled_mean = mean * self.range + self.mean
            scaled_std = std * torch.sqrt(self.range)
            return torch.cat((scaled_mean.unsqueeze(-1), scaled_std.unsqueeze(-1)), -1)

# %%
'''
dataset = read_csv('dataset/elec.txt', sep=";", decimal=",", header=None, skiprows=[0], parse_dates = [[0]], date_parser=date_cv)
dataset.set_index("0", inplace=True)
weekday = pandas.Series(dataset.index[:].weekday, dtype='int32')
hour = pandas.Series(dataset.index[:].hour, dtype='int32')
minute = pandas.Series(dataset.index[:].minute, dtype='int32')
dataset.insert(len(dataset.columns), 'weekday', weekday.values)
dataset.insert(len(dataset.columns), 'hour', hour.values)
dataset.insert(len(dataset.columns), 'min', minute.values)
dataset.index.name = 'date'
dataset = dataset[35042:]
print(dataset.head(5))
'''
# Out:
# '\ndataset = read_csv(\'dataset/elec.txt\', sep=";", decimal=",", header=None, skiprows=[0], parse_dates = [[0]], date_parser=date_cv)\ndataset.set_index("0", inplace=True)\nweekday = pandas.Series(dataset.index[:].weekday, dtype=\'int32\')\nhour = pandas.Series(dataset.index[:].hour, dtype=\'int32\')\nminute = pandas.Series(dataset.index[:].minute, dtype=\'int32\')\ndataset.insert(len(dataset.columns), \'weekday\', weekday.values)\ndataset.insert(len(dataset.columns), \'hour\', hour.values)\ndataset.insert(len(dataset.columns), \'min\', minute.values)\ndataset.index.name = \'date\'\ndataset = dataset[35042:]\nprint(dataset.head(5))\n'

# %%
df.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# 6    float64
# dtype: object

# %%
df
# Out:
#                    0         1         2         3         4         5  \
# date
# 2021-01-01  0.783145  1.791637  1.232552  0.840484  2.574781  2.073036
# 2021-01-02  0.802525  1.878461  1.335720  1.294877  2.680986  2.630597
# 2021-01-03  0.822589  1.270161  1.374417  0.981885  2.092750  2.356302
# 2021-01-04  0.585755  1.379239  1.001110  1.104327  1.964994  2.105437
# 2021-01-05  0.297213  1.537773  1.766846  1.676470  1.834986  3.443316
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  0.896679  0.993697 -0.166995 -0.708858  1.890376 -0.875853
# 2021-12-28  1.327768  0.512467  0.555682 -0.143915  1.840235  0.411768
# 2021-12-29  1.356415  0.426705  0.427134 -0.565109  1.783120 -0.137975
# 2021-12-30  1.455753  1.077160  0.224730  0.245666  2.532913  0.470396
# 2021-12-31  1.891067  0.923843  0.898264  0.258435  2.814910  1.156700
#
#                    6
# date
# 2021-01-01  4.647817
# 2021-01-02  5.311583
# 2021-01-03  4.449052
# 2021-01-04  4.070431
# 2021-01-05  5.278302
# ...              ...
# 2021-12-27  1.014524
# 2021-12-28  2.252003
# 2021-12-29  1.645145
# 2021-12-30  3.003309
# 2021-12-31  3.971610
#
# [365 rows x 7 columns]

# %%
df.to_csv('dataset/test1.csv')

# %%
#for 
values = df.values
groups = [0, 1, 2,3,4,5,6]
i = 1
fig = pyplot.figure()
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[1:400, group])
    pyplot.title(df.columns[group], y=0, loc='right')
    i += 1
fig.subplots_adjust(hspace=0.5)
pyplot.show()

# %%
class MyDataset(Dataset):
    def __len__(self):
        return self.dataset_size
    def __getitem__(self, idx):
        rel_time = torch.from_numpy(np.arange(0, self.ctx_win_len) * self.resolution).unsqueeze(1).float().to(self.dev)
        abs_time = torch.from_numpy(np.arange(idx, idx + self.ctx_win_len) * self.resolution).unsqueeze(1).float().to(
            self.dev)
        if (self.num_time_indx == 2):  
            out = torch.cat((rel_time, abs_time, self.scaled[idx: idx + self.ctx_win_len, :]), -1).unsqueeze(0)
        if (self.num_time_indx == 1):  
            out = torch.cat((rel_time, self.scaled[idx: idx + self.ctx_win_len, :]), -1).unsqueeze(0)
        if (self.num_time_indx == 0):  
            out = self.scaled[idx: idx + self.ctx_win_len, :].unsqueeze(0)
        return torch.squeeze(out, 0)
    def get_train_test_samplers(self, train_test_split):
        indices = list(range(self.dataset_size))
        split = int(np.floor(train_test_split * self.dataset_size))
        train_indices, test_indices = indices[: split - self.ctx_win_len], indices[split-self.ctx_win_len: ]
        return SubsetRandomSampler(train_indices), SubsetRandomSampler(test_indices)
    def plot_corr(self, df, size=10):
        corr = df.corr()
        fig, ax = plt.subplots(figsize=(size, size))
        ax.matshow(corr)
        plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
        plt.yticks(range(len(corr.columns)), corr.columns)

# %%
class Test_pre(MyDataset):
    def __init__(self, csv_file, dev, ctx_win_len, num_time_indx=1):
        self.num_time_indx = num_time_indx
        self.dev = dev
        df = read_csv('dataset/test1.csv',index_col=0)
        self.ctx_win_len = ctx_win_len
        values = df.values
        values = values.astype('float32')
        self.scaled = values
        self.dataset_size = self.scaled.shape[0]
        self.scaled = torch.from_numpy(self.scaled).float().to(dev)
        self.resolution = 1

# %%
params = _params_
dataset = Test_pre(csv_file=params['data_file'], dev=device, ctx_win_len=params['ctx_win_len'], num_time_indx=params['num_time_idx'])

# %%
'''
dataset = electricity_pre(csv_file=params['data_file'], dev=device, ctx_win_len=params['ctx_win_len'], num_time_indx=params['num_time_idx'])
'''
# Out:
# "\ndataset = electricity_pre(csv_file=params['data_file'], dev=device, ctx_win_len=params['ctx_win_len'], num_time_indx=params['num_time_idx'])\n"

# %%
num_covariates = params['num_covariates']
num_time_idx = params['num_time_idx']
num_targets = params['num_targets']
input_dim = num_time_idx + num_targets + num_covariates
'''
Size of the entire context window utilized during training
can be divided into 2 sections - first: conditioning context with input data points and network predictions conditioned on real data; 
and other one is  prediction context, where network predictions are conditioned on network output from the ealrier steps.
'''
ctx_win_len = params['ctx_win_len']
cond_win_len = params['cond_win_len']
pred_win_len = ctx_win_len - cond_win_len - 1
batch_size = params['batch_size']

# %%
model = model(num_lstms=params['num_lstms'], input_dim=input_dim, output_dim=params['num_targets'],hidden_dim=params['hidden_dim']).to(device)
optimizer = optim.Adam(model.parameters(), params['lr'])
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=params['lr_step_size'], gamma=params['lr_gamma'])

# %%
train_sampler, test_sampler = dataset.get_train_test_samplers(params['train_test_split'])
train_dataloader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, shuffle=False, num_workers=0)
test_dataloader = DataLoader(dataset, batch_size=1, sampler=test_sampler,shuffle=False, num_workers=0)
max_batches_per_epoch = params['max_batches_per_epoch']
num_epochs = params['num_epochs']

# %%
losses = []
batch_num = 1
utils = utils(device, params)
# Trainin loop
def train():
    for epoch in range(0, num_epochs):
        batch_num = 0
        for i, batch in enumerate(train_dataloader):
            if batch_num > max_batches_per_epoch:
                break    
            input, target, covariates = utils.split_batch(batch) #splitting batches : issue with sequence
            #conditioning window input,Prediction window , model op conditioned on previous values
            # model output for the previous step
            input_cond = input[:, 0:cond_win_len, :]
            input_cond, covariates = utils.scale(input_cond, covariates)
            optimizer.zero_grad()
            #forward pass
            out = model(input_cond, covariates, future=pred_win_len)
            out = utils.invert_scale(out, probabalistic=True)
            #rescale
            loss = model.NLL(out, target)
            #loss calc
            loss.backward()
            scheduler.step()
            optimizer.step()
            loss = loss.item()
            losses.append(loss)
            print(f"epoch:{epoch} /{num_epochs}| batch:{batch_num}:loss:{loss}")
            batch_num = batch_num + 1
    return model, losses

# %%
model, losses = train()
data='elec'# electricity dataset
date_=str(now).replace(" ", "")
model_save_ = f"{data}_epochs{params['num_epochs']}_{ date_ }"
torch.save(model.state_dict(), model_save_+".pth")
# Out:
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 0
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:0 /100| batch:0:loss:19.217973709106445
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 1
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:0 /100| batch:1:loss:16.75732421875
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 2
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:0 /100| batch:2:loss:13.384259223937988
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 3
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:0 /100| batch:3:loss:10.091255187988281
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 4
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:0 /100| batch:4:loss:9.319722175598145
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 5
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:0 /100| batch:5:loss:9.70840835571289
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 6
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:1 /100| batch:0:loss:9.800995826721191
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 7
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:1 /100| batch:1:loss:9.684347152709961
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 8
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:1 /100| batch:2:loss:9.513198852539062
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 9
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:1 /100| batch:3:loss:9.782215118408203
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 10
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:1 /100| batch:4:loss:9.253954887390137
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 11
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:1 /100| batch:5:loss:8.922035217285156
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 12
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:2 /100| batch:0:loss:9.733214378356934
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 13
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:2 /100| batch:1:loss:9.159382820129395
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 14
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:2 /100| batch:2:loss:9.310794830322266
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 15
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:2 /100| batch:3:loss:9.055742263793945
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 16
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:2 /100| batch:4:loss:9.277442932128906
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 17
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:2 /100| batch:5:loss:9.189532279968262
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 18
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:3 /100| batch:0:loss:9.335165023803711
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 19
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:3 /100| batch:1:loss:9.044440269470215
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 20
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:3 /100| batch:2:loss:9.033666610717773
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 21
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:3 /100| batch:3:loss:9.051961898803711
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 22
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:3 /100| batch:4:loss:9.08374309539795
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 23
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:3 /100| batch:5:loss:9.4213285446167
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 24
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:4 /100| batch:0:loss:8.96412467956543
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 25
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:4 /100| batch:1:loss:9.139010429382324
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 26
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:4 /100| batch:2:loss:9.224836349487305
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 27
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:4 /100| batch:3:loss:9.225631713867188
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 28
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:4 /100| batch:4:loss:9.172486305236816
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 29
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:4 /100| batch:5:loss:9.117593765258789
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 30
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:5 /100| batch:0:loss:9.018157005310059
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 31
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:5 /100| batch:1:loss:9.264937400817871
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 32
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:5 /100| batch:2:loss:9.152350425720215
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 33
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:5 /100| batch:3:loss:8.820493698120117
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 34
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:5 /100| batch:4:loss:9.147847175598145
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 35
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:5 /100| batch:5:loss:8.722848892211914
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 36
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:6 /100| batch:0:loss:9.229850769042969
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 37
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:6 /100| batch:1:loss:9.051566123962402
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 38
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:6 /100| batch:2:loss:8.934575080871582
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 39
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:6 /100| batch:3:loss:8.977612495422363
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 40
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:6 /100| batch:4:loss:8.795711517333984
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 41
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:6 /100| batch:5:loss:8.975451469421387
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 42
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:7 /100| batch:0:loss:8.929794311523438
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 43
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:7 /100| batch:1:loss:8.841693878173828
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 44
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:7 /100| batch:2:loss:8.51849365234375
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 45
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:7 /100| batch:3:loss:8.724438667297363
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 46
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:7 /100| batch:4:loss:8.510537147521973
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 47
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:7 /100| batch:5:loss:8.323714256286621
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 48
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:8 /100| batch:0:loss:8.422402381896973
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 49
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:8 /100| batch:1:loss:8.129129409790039
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 50
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:8 /100| batch:2:loss:8.06658935546875
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 51
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:8 /100| batch:3:loss:7.999944686889648
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 52
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:8 /100| batch:4:loss:7.8888397216796875
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 53
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:8 /100| batch:5:loss:7.993653774261475
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 54
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:9 /100| batch:0:loss:7.738171100616455
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 55
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:9 /100| batch:1:loss:7.805017471313477
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 56
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:9 /100| batch:2:loss:8.693351745605469
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 57
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:9 /100| batch:3:loss:7.712836265563965
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 58
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:9 /100| batch:4:loss:7.625792980194092
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 59
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:9 /100| batch:5:loss:20.68825912475586
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 60
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:10 /100| batch:0:loss:7.894479751586914
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 61
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:10 /100| batch:1:loss:8.261247634887695
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 62
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:10 /100| batch:2:loss:8.291436195373535
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 63
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:10 /100| batch:3:loss:8.160028457641602
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 64
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:10 /100| batch:4:loss:8.346628189086914
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 65
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:10 /100| batch:5:loss:8.610189437866211
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 66
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:11 /100| batch:0:loss:8.343450546264648
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 67
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:11 /100| batch:1:loss:8.375120162963867
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 68
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:11 /100| batch:2:loss:8.803804397583008
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 69
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:11 /100| batch:3:loss:8.441078186035156
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 70
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:11 /100| batch:4:loss:8.821450233459473
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 71
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:11 /100| batch:5:loss:8.7301607131958
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 72
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:12 /100| batch:0:loss:8.649422645568848
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 73
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:12 /100| batch:1:loss:8.655136108398438
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 74
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:12 /100| batch:2:loss:8.380833625793457
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 75
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:12 /100| batch:3:loss:8.742514610290527
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 76
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:12 /100| batch:4:loss:8.799629211425781
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 77
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:12 /100| batch:5:loss:8.36844253540039
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 78
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:13 /100| batch:0:loss:8.414848327636719
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 79
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:13 /100| batch:1:loss:8.511056900024414
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 80
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:13 /100| batch:2:loss:8.383864402770996
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 81
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:13 /100| batch:3:loss:8.49061107635498
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 82
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:13 /100| batch:4:loss:8.638849258422852
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 83
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:13 /100| batch:5:loss:8.482751846313477
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 84
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:14 /100| batch:0:loss:8.521615982055664
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 85
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:14 /100| batch:1:loss:8.444034576416016
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 86
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:14 /100| batch:2:loss:8.460365295410156
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 87
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:14 /100| batch:3:loss:8.32596206665039
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 88
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:14 /100| batch:4:loss:8.358040809631348
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 89
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:14 /100| batch:5:loss:8.318195343017578
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 90
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:15 /100| batch:0:loss:8.226178169250488
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 91
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:15 /100| batch:1:loss:8.269088745117188
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 92
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:15 /100| batch:2:loss:8.27626895904541
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 93
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:15 /100| batch:3:loss:8.288113594055176
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 94
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:15 /100| batch:4:loss:8.295858383178711
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 95
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:15 /100| batch:5:loss:8.247482299804688
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 96
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:16 /100| batch:0:loss:8.106568336486816
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 97
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:16 /100| batch:1:loss:8.024307250976562
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 98
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:16 /100| batch:2:loss:8.279635429382324
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 99
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:16 /100| batch:3:loss:8.078543663024902
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 100
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:16 /100| batch:4:loss:7.995445728302002
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 101
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:16 /100| batch:5:loss:7.806368350982666
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 102
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:17 /100| batch:0:loss:8.030006408691406
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 103
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:17 /100| batch:1:loss:8.104872703552246
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 104
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:17 /100| batch:2:loss:8.039999008178711
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 105
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:17 /100| batch:3:loss:7.793794631958008
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 106
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:17 /100| batch:4:loss:7.800520420074463
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 107
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:17 /100| batch:5:loss:7.719669342041016
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 108
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:18 /100| batch:0:loss:7.8712615966796875
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 109
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:18 /100| batch:1:loss:7.637201309204102
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 110
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:18 /100| batch:2:loss:7.71328067779541
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 111
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:18 /100| batch:3:loss:7.637073040008545
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 112
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:18 /100| batch:4:loss:7.825736045837402
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 113
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:18 /100| batch:5:loss:7.626923561096191
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 114
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:19 /100| batch:0:loss:7.673473358154297
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 115
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:19 /100| batch:1:loss:7.5784759521484375
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 116
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:19 /100| batch:2:loss:7.542801856994629
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 117
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:19 /100| batch:3:loss:7.436389923095703
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 118
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:19 /100| batch:4:loss:7.484059810638428
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 119
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:19 /100| batch:5:loss:7.605034351348877
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 120
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:20 /100| batch:0:loss:7.720293045043945
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 121
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:20 /100| batch:1:loss:7.412834644317627
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 122
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:20 /100| batch:2:loss:7.5839056968688965
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 123
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:20 /100| batch:3:loss:7.432536602020264
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 124
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:20 /100| batch:4:loss:7.119698524475098
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 125
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:20 /100| batch:5:loss:7.8059797286987305
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 126
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:21 /100| batch:0:loss:7.0446457862854
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 127
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:21 /100| batch:1:loss:7.457810401916504
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 128
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:21 /100| batch:2:loss:7.016634464263916
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 129
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:21 /100| batch:3:loss:6.840479850769043
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 130
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:21 /100| batch:4:loss:20.496196746826172
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 131
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:21 /100| batch:5:loss:9.20497989654541
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 132
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:22 /100| batch:0:loss:10.2794771194458
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 133
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:22 /100| batch:1:loss:9.141613006591797
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 134
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:22 /100| batch:2:loss:8.910646438598633
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 135
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:22 /100| batch:3:loss:9.017498016357422
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 136
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:22 /100| batch:4:loss:9.626233100891113
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 137
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:22 /100| batch:5:loss:10.055501937866211
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 138
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:23 /100| batch:0:loss:10.071431159973145
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 139
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:23 /100| batch:1:loss:10.1503324508667
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 140
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:23 /100| batch:2:loss:9.950338363647461
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 141
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:23 /100| batch:3:loss:9.62195873260498
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 142
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:23 /100| batch:4:loss:9.25685977935791
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 143
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:23 /100| batch:5:loss:9.124189376831055
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 144
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:24 /100| batch:0:loss:8.774726867675781
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 145
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:24 /100| batch:1:loss:8.566032409667969
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 146
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:24 /100| batch:2:loss:8.682031631469727
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 147
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:24 /100| batch:3:loss:8.881913185119629
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 148
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:24 /100| batch:4:loss:8.956592559814453
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 149
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:24 /100| batch:5:loss:8.859313011169434
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 150
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:25 /100| batch:0:loss:8.66390609741211
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 151
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:25 /100| batch:1:loss:8.744621276855469
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 152
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:25 /100| batch:2:loss:8.24017333984375
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 153
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:25 /100| batch:3:loss:8.679779052734375
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 154
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:25 /100| batch:4:loss:8.433334350585938
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 155
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:25 /100| batch:5:loss:8.078648567199707
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 156
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:26 /100| batch:0:loss:8.520814895629883
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 157
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:26 /100| batch:1:loss:8.245281219482422
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 158
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:26 /100| batch:2:loss:8.346976280212402
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 159
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:26 /100| batch:3:loss:8.093420028686523
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 160
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:26 /100| batch:4:loss:8.114713668823242
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 161
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:26 /100| batch:5:loss:8.385797500610352
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 162
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:27 /100| batch:0:loss:8.184414863586426
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 163
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:27 /100| batch:1:loss:8.27976131439209
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 164
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:27 /100| batch:2:loss:8.145968437194824
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 165
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:27 /100| batch:3:loss:8.113607406616211
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 166
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:27 /100| batch:4:loss:8.124229431152344
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 167
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:27 /100| batch:5:loss:8.206039428710938
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 168
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:28 /100| batch:0:loss:8.34072208404541
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 169
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:28 /100| batch:1:loss:7.892630577087402
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 170
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:28 /100| batch:2:loss:8.054718971252441
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 171
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:28 /100| batch:3:loss:8.150510787963867
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 172
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:28 /100| batch:4:loss:7.813728332519531
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 173
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:28 /100| batch:5:loss:7.776525020599365
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 174
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:29 /100| batch:0:loss:7.864682197570801
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 175
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:29 /100| batch:1:loss:7.752716064453125
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 176
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:29 /100| batch:2:loss:7.981790542602539
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 177
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:29 /100| batch:3:loss:7.799294471740723
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 178
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:29 /100| batch:4:loss:8.062858581542969
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 179
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:29 /100| batch:5:loss:7.947299480438232
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 180
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:30 /100| batch:0:loss:7.549429416656494
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 181
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:30 /100| batch:1:loss:7.892849922180176
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 182
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:30 /100| batch:2:loss:7.706820011138916
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 183
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:30 /100| batch:3:loss:7.853882789611816
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 184
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:30 /100| batch:4:loss:7.7024455070495605
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 185
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:30 /100| batch:5:loss:7.601149559020996
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 186
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:31 /100| batch:0:loss:7.74119758605957
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 187
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:31 /100| batch:1:loss:7.608363151550293
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 188
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:31 /100| batch:2:loss:7.991352558135986
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 189
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:31 /100| batch:3:loss:7.541896820068359
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 190
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:31 /100| batch:4:loss:7.523653507232666
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 191
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:31 /100| batch:5:loss:7.812107086181641
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 192
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# ...
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:89 /100| batch:2:loss:0.1390131711959839
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 537
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:89 /100| batch:3:loss:0.8015279769897461
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 538
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:89 /100| batch:4:loss:0.3398245573043823
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 539
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:89 /100| batch:5:loss:0.6635662317276001
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 540
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:90 /100| batch:0:loss:0.16764074563980103
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 541
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:90 /100| batch:1:loss:0.3780876398086548
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 542
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:90 /100| batch:2:loss:0.2740092873573303
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 543
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:90 /100| batch:3:loss:-0.14642810821533203
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 544
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:90 /100| batch:4:loss:0.02251124382019043
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 545
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:90 /100| batch:5:loss:-0.2469521164894104
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 546
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:91 /100| batch:0:loss:-0.04720115661621094
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 547
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:91 /100| batch:1:loss:0.08513200283050537
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 548
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:91 /100| batch:2:loss:0.06377685070037842
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 549
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:91 /100| batch:3:loss:0.4051077365875244
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 550
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:91 /100| batch:4:loss:0.5036550760269165
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 551
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:91 /100| batch:5:loss:-0.03724813461303711
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 552
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:92 /100| batch:0:loss:0.3355611562728882
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 553
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:92 /100| batch:1:loss:0.18985086679458618
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 554
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:92 /100| batch:2:loss:1.0709598064422607
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 555
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:92 /100| batch:3:loss:-0.11741262674331665
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 556
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:92 /100| batch:4:loss:0.39818722009658813
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 557
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:92 /100| batch:5:loss:-0.22434908151626587
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 558
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:93 /100| batch:0:loss:0.3955932855606079
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 559
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:93 /100| batch:1:loss:-0.05286985635757446
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 560
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:93 /100| batch:2:loss:0.030478060245513916
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 561
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:93 /100| batch:3:loss:-0.04053217172622681
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 562
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:93 /100| batch:4:loss:0.10345333814620972
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 563
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:93 /100| batch:5:loss:-0.08530253171920776
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 564
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:94 /100| batch:0:loss:0.30050957202911377
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 565
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:94 /100| batch:1:loss:0.5358904600143433
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 566
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:94 /100| batch:2:loss:0.5282678604125977
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 567
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:94 /100| batch:3:loss:0.15491944551467896
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 568
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:94 /100| batch:4:loss:0.018829822540283203
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 569
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:94 /100| batch:5:loss:0.5509636998176575
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 570
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:95 /100| batch:0:loss:-0.06202274560928345
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 571
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:95 /100| batch:1:loss:0.3443492650985718
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 572
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:95 /100| batch:2:loss:-0.04014045000076294
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 573
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:95 /100| batch:3:loss:0.390019953250885
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 574
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:95 /100| batch:4:loss:0.3700109124183655
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 575
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:95 /100| batch:5:loss:0.029644489288330078
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 576
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:96 /100| batch:0:loss:0.302551805973053
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 577
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:96 /100| batch:1:loss:0.2742016911506653
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 578
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:96 /100| batch:2:loss:0.2766748070716858
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 579
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:96 /100| batch:3:loss:0.9583007097244263
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 580
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:96 /100| batch:4:loss:0.6031700372695923
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 581
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:96 /100| batch:5:loss:0.34399139881134033
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 582
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:97 /100| batch:0:loss:-0.021429717540740967
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 583
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:97 /100| batch:1:loss:0.6046851277351379
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 584
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:97 /100| batch:2:loss:0.4961917996406555
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 585
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:97 /100| batch:3:loss:0.5316756367683411
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 586
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:97 /100| batch:4:loss:0.4139869213104248
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 587
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:97 /100| batch:5:loss:-0.27111971378326416
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 588
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:98 /100| batch:0:loss:0.6309863924980164
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 589
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:98 /100| batch:1:loss:0.6574705839157104
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 590
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:98 /100| batch:2:loss:0.27177494764328003
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 591
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:98 /100| batch:3:loss:0.49279260635375977
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 592
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:98 /100| batch:4:loss:-0.05378812551498413
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 593
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:98 /100| batch:5:loss:0.2536340355873108
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 594
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:99 /100| batch:0:loss:-0.25954604148864746
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 595
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:99 /100| batch:1:loss:0.42292356491088867
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 596
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:99 /100| batch:2:loss:0.2978546619415283
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 597
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:99 /100| batch:3:loss:-0.3680226802825928
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 598
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:99 /100| batch:4:loss:0.4846888780593872
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 599
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:99 /100| batch:5:loss:-0.11007583141326904

# %%
model
# Out:
# model(
#   (lstms): ModuleList(
#     (0): LSTMCell(7, 64)
#     (1): LSTMCell(64, 64)
#   )
#   (mean): Linear(in_features=64, out_features=7, bias=True)
#   (std): Linear(in_features=64, out_features=7, bias=True)
# )

# %%
test_dataloader_iter = iter(test_dataloader)
for i in range(0, 1):
    test_batch = next(test_dataloader_iter)
    with torch.no_grad():
        input, target, covariates = utils.split_batch(test_batch)
        input, covariates = utils.scale(input, covariates)
        pred = model(input[:, 0:cond_win_len, :], covariates, future=pred_win_len)
        pred = utils.invert_scale(pred, True)
        loss = model.NLL(pred, target)
        print("loss (prediction): {0}".format(loss))
        preds = pred[0, :, :, :].detach().cpu().numpy()
        targets = target[0, :, :].detach().cpu().numpy()
        preds[:, 4:5, 0]=np.sum(preds[:, 0:2, 0:1],axis=1)
        preds[:, 4:5, 1]=np.sum(preds[:, 0:2, 1:2],axis=1)
        preds[:, 5:6, 0]=np.sum(preds[:, 2:4, 0:1],axis=1)
        preds[:, 5:6, 1]=np.sum(preds[:, 2:4, 1:2],axis=1)
        preds[:, 6:7, 0]=np.sum(preds[:, 4:6, 0:1],axis=1)
        preds[:, 6:7, 1]=np.sum(preds[:, 4:6, 1:2],axis=1)
    for j in range(num_targets):
        pred = preds[:, j, 0]  
        std = preds[:, j, 1]  
        target = targets[:, j]
        plt.figure()

        plt.xlabel('x')
        plt.ylabel('y')
        plt.xticks()
        plt.yticks()
        plt.plot(np.arange(len(target)), target, 'r', linewidth=2.0)
        plt.plot(np.arange(cond_win_len), pred[0:cond_win_len], 'b', linewidth=2.0)
        plt.plot(np.arange(cond_win_len, cond_win_len + pred_win_len), pred[cond_win_len:], 'g' + ':',
                 linewidth=2.0)
        plt.fill_between(np.arange(len(target)), pred - std, pred + std, color='cyan', alpha=0.5)
        plt.fill_between(np.arange(len(target)), pred - 2 * std, pred + 2 * std, color='cyan', alpha=0.2)
# Out:
# torch.Size([1, 79, 7, 2]) torch.Size([1, 79, 7])
# 600
# ........NLL.........
# squeeze torch.Size([1, 79, 7]) torch.Size([1, 79, 7])
# torch.Size([1, 79, 7]) torch.Size([1, 79, 7])
# torch.Size([1, 79, 4])
# loss (prediction): 8.721563339233398
