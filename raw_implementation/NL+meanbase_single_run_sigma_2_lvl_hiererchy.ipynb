# %%
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
from matplotlib import pyplot as plt
import datetime as dt
from torch.utils.data.dataloader import DataLoader
from datetime import datetime
from dataset.electricity_dataset import electricity_pre
from pandas import read_csv
import pandas
from datetime import datetime
import os
from matplotlib import pyplot
import warnings
from pandas import read_csv, DataFrame
import os
import torch
from pandas import read_csv
from datetime import datetime
import os
from matplotlib import pyplot
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import LabelEncoder
from torch.utils.data.dataset import Dataset
from torch.utils.data.dataloader import DataLoader
from torch.utils.data.sampler import Sampler, SubsetRandomSampler
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
gc =0

# %%
import random
np.set_printoptions(precision=4)
#array_=np.random.random_sample((365,2))
array_ = np.sin((np.arange(365)/10+3*np.random.random_sample(2).reshape(-1,1)).T)+np.random.random_sample((365,2))
array_1 = np.sin((np.arange(365)/10+2*np.random.random_sample(2).reshape(-1,1)).T)+np.random.random_sample((365,2))

# %%
fnl_=np.concatenate([array_,array_1, array_.sum(1)[:,None], array_1.sum(1)[:,None]], -1)

# %%
fnl_.shape
# Out:
# (365, 6)

# %%
start_date = dt.date(2021, 1, 1)
end_date   = dt.date(2022, 1, 1)
dates_ = [ start_date + dt.timedelta(n) for n in range(int ((end_date - start_date).days))]

# %%
dts=[]
for i in dates_ :
    dts.append(i.strftime("%Y-%m-%d"))

# %%
array_.shape
# Out:
# (365, 2)

# %%
#np.array(dts)

# %%
import pandas as pd

# %%
df = pd.DataFrame(fnl_)

# %%
df['date'] = pd.Series(np.array(dts), index=df.index)

# %%
df.set_index("date", inplace=True)

# %%
df[6] = df[4] + df[5]

# %%
df
# Out:
#                    0         1         2         3         4         5  \
# date
# 2021-01-01  1.472609  0.635456  1.193696  1.174819  2.108065  2.368514
# 2021-01-02  1.302049  1.255633  1.821513  1.597815  2.557683  3.419328
# 2021-01-03  1.344571  1.219931  1.837987  1.035690  2.564502  2.873677
# 2021-01-04  1.131169  1.010828  1.329999  1.023101  2.141998  2.353100
# 2021-01-05  1.325715  1.009060  1.708343  1.925103  2.334775  3.633446
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  0.604779 -0.262852  0.529717  0.625030  0.341927  1.154746
# 2021-12-28  1.412749 -0.718690  1.173074  0.038560  0.694059  1.211634
# 2021-12-29  1.196427 -0.706285  0.355743  0.559427  0.490142  0.915171
# 2021-12-30  1.627107 -0.050155  0.678232  0.217777  1.576953  0.896009
# 2021-12-31  1.692687 -0.530243  1.083896  0.345208  1.162444  1.429103
#
#                    6
# date
# 2021-01-01  4.476580
# 2021-01-02  5.977010
# 2021-01-03  5.438179
# 2021-01-04  4.495098
# 2021-01-05  5.968221
# ...              ...
# 2021-12-27  1.496674
# 2021-12-28  1.905693
# 2021-12-29  1.405312
# 2021-12-30  2.472962
# 2021-12-31  2.591547
#
# [365 rows x 7 columns]

# %%
warnings.filterwarnings('ignore')
now = datetime.now()
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
GC=[]

# %%
#  probabalistic model with likelihood function
class model(nn.Module):
    def __init__(self, num_lstms, input_dim, output_dim=1, hidden_dim=64):
        super(model, self).__init__()
        self.lstm_out = hidden_dim
        self.num_lstms = num_lstms
        lstms = []
        
        lstms.append(nn.LSTMCell(input_dim, self.lstm_out))
        for i in range(1, self.num_lstms):
            lstms.append(nn.LSTMCell(self.lstm_out, self.lstm_out))
        self.lstms = nn.ModuleList(lstms)
        # μ and σ  distibution -> next point for every t_i.prediction length is from output dimensions
        self.mean = nn.Linear(self.lstm_out, output_dim)
        self.std = nn.Linear(self.lstm_out, output_dim)

    def forward(self, input, covariates, future = 0):
        dev = input.device
        means = torch.Tensor().to(dev)
        stds = torch.Tensor().to(dev)
        outputs = []
        h_t = []
        c_t = []
        cond_ctx_len = input.size(1)
        pred_ctx_len = future
        #for covariartes concat input and covariates
        if covariates.shape[2] != 0:
            input = torch.cat((input, covariates[:, 0:cond_ctx_len, :]), 2)
        for i in range(0, self.num_lstms):
            h_t.append(torch.zeros(input.size(0), self.lstm_out, dtype=torch.float).to(dev))
            c_t.append(torch.zeros(input.size(0), self.lstm_out, dtype=torch.float).to(dev))
        '''
         h(hidden state),c(cell state)-> output of Lstm cell, h(i)-> passed to lstm(i+1) cell, 
         h(i) and c(i) are recurrent for lstm cell(i+1) 
         and the output from previous cell '''
        for i, input_t in enumerate(input.chunk(input.size(1), dim=1)):
            h_t[0], c_t[0] = self.lstms[0](input_t.squeeze(1), (h_t[0], c_t[0])) #first cell ->concat of input and covariates, recurrent input 
            for n in range(1, self.num_lstms):
                h_t[n], c_t[n] = self.lstms[n](h_t[n - 1], (h_t[n], c_t[n]))#susquent cells-> prev. output from stack, recurrent input
            mean = self.mean(h_t[n])
            std = self.std(h_t[n])
            means = torch.cat((means, mean.unsqueeze(1)), 1)
            stds = torch.cat((stds, std.unsqueeze(1)), 1)
        stds = self.softplus(stds)
        for i in range(future):
            output_t = torch.cat((mean, covariates[:, cond_ctx_len + i, :]), 1)
            h_t[0], c_t[0] = self.lstms[0](output_t, (h_t[0], c_t[0]))
            for n in range(1, self.num_lstms):
                h_t[n], c_t[n] = self.lstms[n](h_t[n - 1], (h_t[n], c_t[n]))
            mean = self.mean(h_t[n])
            std = self.std(h_t[n])
            std = self.softplus(std) # avoid infinties
            means = torch.cat((means, mean.unsqueeze(1)), 1)
            stds = torch.cat((stds, std.unsqueeze(1)), 1)
        means = means.unsqueeze(-1)
        stds = stds.unsqueeze(-1)
        outputs = torch.cat((means, stds), -1)
        return outputs

    def sample(self, mean, std):

        normal_dist = torch.distributions.normal.Normal(mean, std)
        return normal_dist.sample()

    def softplus(self, x):
        softplus = torch.log(1+torch.exp(x))
        softplus = torch.where(softplus==float('inf'), x, softplus)
        return softplus

    def NLL(self, outputs, truth):#negative log liklihood
        print(outputs.shape,truth.shape)
        mean, std = torch.split(outputs, 1, dim=3)
        #print('normal',mean.shape,std.shape)
        global gc
        #print(outputs,truth)
        print(gc)
        gc=gc+1
        print(f"{'NLL':.^20}")
        mean = mean.squeeze(3)
        std = std.squeeze(3)
        print('squeeze',mean.shape,std.shape)
        
        print(mean.shape,truth.shape)
        global GC   
        GC.append([mean,truth])
        diff = torch.sub(truth[:, :, :4], mean[:, :, :4])
        print(diff.shape)       
        
        loss = torch.mean(torch.div(torch.pow(diff, 2), torch.pow(std[:, :, :4], 2))) + 2*torch.mean(torch.log(std[:, :, :4])) + \
                                torch.mean(torch.abs(torch.sub(truth[:, :,4:5],mean[:, :, 0:1]+ mean[:, :, 1:2]))) + \
                                 torch.mean(torch.abs(torch.sub(truth[:, :,5:6],mean[:, :, 2:3]+ mean[:, :, 3:4])))  + \
                                 torch.mean(torch.abs(torch.sub(truth[:, :,6:7],mean[:, :, 0:1]+ mean[:, :, 1:2]+mean[:, :, 2:3]+ mean[:, :, 3:4])))
        
        #print('loss',loss.shape)
        return loss

# %%
def date_cv(x):
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

# %%
_params_ = {'lr': 0.001,
    'lr_step_size': 100,
    'lr_gamma': 1,
    'ctx_win_len': 80,
    'cond_win_len': 20,
    'batch_size': 32,
    'num_covariates': 0,
    'total_num_covariates': 0,
    'num_time_idx': 0,
    'num_targets': 7,
    'total_num_targets': 7,
    'num_lstms': 2,
    'hidden_dim': 64,
    'max_batches_per_epoch': 200,
    'num_epochs': 100,
    'data_file': 'test1.csv',
    'train_test_split': 0.7
}

ls_params = _params_
ls_params['num_covariates'] = 0

# %%
class utils:
    def __init__(self, dev,_params):
        self.min = 0
        self.max = 0
        self.range = 0
        self.mean = 0
        self.dev = dev
        self._params = _params

    def NRMSE(self, input, target):
        return np.sqrt(torch.nn.functional.mse_loss(input, target).item()) / torch.mean(torch.abs(target))

    def NormDeviation(self, input, target):
        return torch.mean(torch.abs(input - target)) / torch.mean(torch.abs(target))

    def MAE(self, input, target):
        return torch.mean(torch.abs(input - target))

    def split_batch(self, batch):
        num_time_idx = self._params['num_time_idx']
        num_targets = self._params['num_targets']
        total_num_targets = self._params['total_num_targets']
        num_covariates = self._params['num_covariates']    
        b = num_time_idx
        time_idx = batch[:, 1::, :b].to(self.dev).float()
        e = b + num_targets
        input = batch[:, 0:-1, b: e].to(self.dev).float()
        target = batch[:, 1::, b: e].to(self.dev).float()
        e = e - num_targets + total_num_targets
        total_num_covariates = batch.shape[2] - e + 1  
        covariates = time_idx
        b = e
        e = b + num_covariates
        if (num_covariates > 0):
            covariates = torch.cat((time_idx, batch[:, 1::, b: e]), -1)
        return input, target, covariates

    def scale(self, input, covariates):
        
        self.mean = torch.mean(input, dim=1).unsqueeze(1)
        input = input - self.mean
        min = torch.min(input, dim=1)[0].unsqueeze(1)
        max = torch.max(input, dim=1)[0].unsqueeze(1)
        self.range = max - min
        self.range[self.range < 1e-5] = 1e-5
        input = input / self.range

        num_covariates = self._params['num_covariates']
        if (num_covariates > 0):
            mean = torch.mean(covariates, dim=1).unsqueeze(1)
            covariates = covariates - mean
            min = torch.min(covariates, dim=1)[0].unsqueeze(1)
            max = torch.max(covariates, dim=1)[0].unsqueeze(1)
            range = max - min
            range[range < 1e-5] = 1e-5
            covariates = covariates / range
        return input, covariates

    def invert_scale(self, input, probabalistic=False):
        if probabalistic == False:
            return input * self.range + self.mean
        else:
            mean = input[:, :, :, 0]
            std = input[:, :, :, 1]
            scaled_mean = mean * self.range + self.mean
            scaled_std = std * torch.sqrt(self.range)
            return torch.cat((scaled_mean.unsqueeze(-1), scaled_std.unsqueeze(-1)), -1)

# %%
'''
dataset = read_csv('dataset/elec.txt', sep=";", decimal=",", header=None, skiprows=[0], parse_dates = [[0]], date_parser=date_cv)
dataset.set_index("0", inplace=True)
weekday = pandas.Series(dataset.index[:].weekday, dtype='int32')
hour = pandas.Series(dataset.index[:].hour, dtype='int32')
minute = pandas.Series(dataset.index[:].minute, dtype='int32')
dataset.insert(len(dataset.columns), 'weekday', weekday.values)
dataset.insert(len(dataset.columns), 'hour', hour.values)
dataset.insert(len(dataset.columns), 'min', minute.values)
dataset.index.name = 'date'
dataset = dataset[35042:]
print(dataset.head(5))
'''
# Out:
# '\ndataset = read_csv(\'dataset/elec.txt\', sep=";", decimal=",", header=None, skiprows=[0], parse_dates = [[0]], date_parser=date_cv)\ndataset.set_index("0", inplace=True)\nweekday = pandas.Series(dataset.index[:].weekday, dtype=\'int32\')\nhour = pandas.Series(dataset.index[:].hour, dtype=\'int32\')\nminute = pandas.Series(dataset.index[:].minute, dtype=\'int32\')\ndataset.insert(len(dataset.columns), \'weekday\', weekday.values)\ndataset.insert(len(dataset.columns), \'hour\', hour.values)\ndataset.insert(len(dataset.columns), \'min\', minute.values)\ndataset.index.name = \'date\'\ndataset = dataset[35042:]\nprint(dataset.head(5))\n'

# %%
df.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# 6    float64
# dtype: object

# %%
df
# Out:
#                    0         1         2         3         4         5  \
# date
# 2021-01-01  1.472609  0.635456  1.193696  1.174819  2.108065  2.368514
# 2021-01-02  1.302049  1.255633  1.821513  1.597815  2.557683  3.419328
# 2021-01-03  1.344571  1.219931  1.837987  1.035690  2.564502  2.873677
# 2021-01-04  1.131169  1.010828  1.329999  1.023101  2.141998  2.353100
# 2021-01-05  1.325715  1.009060  1.708343  1.925103  2.334775  3.633446
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  0.604779 -0.262852  0.529717  0.625030  0.341927  1.154746
# 2021-12-28  1.412749 -0.718690  1.173074  0.038560  0.694059  1.211634
# 2021-12-29  1.196427 -0.706285  0.355743  0.559427  0.490142  0.915171
# 2021-12-30  1.627107 -0.050155  0.678232  0.217777  1.576953  0.896009
# 2021-12-31  1.692687 -0.530243  1.083896  0.345208  1.162444  1.429103
#
#                    6
# date
# 2021-01-01  4.476580
# 2021-01-02  5.977010
# 2021-01-03  5.438179
# 2021-01-04  4.495098
# 2021-01-05  5.968221
# ...              ...
# 2021-12-27  1.496674
# 2021-12-28  1.905693
# 2021-12-29  1.405312
# 2021-12-30  2.472962
# 2021-12-31  2.591547
#
# [365 rows x 7 columns]

# %%
df.to_csv('dataset/test1.csv')

# %%
#for 
values = df.values
groups = [0, 1, 2,3,4,5,6]
i = 1
fig = pyplot.figure()
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[1:400, group])
    pyplot.title(df.columns[group], y=0, loc='right')
    i += 1
fig.subplots_adjust(hspace=0.5)
pyplot.show()

# %%
class MyDataset(Dataset):
    def __len__(self):
        return self.dataset_size
    def __getitem__(self, idx):
        rel_time = torch.from_numpy(np.arange(0, self.ctx_win_len) * self.resolution).unsqueeze(1).float().to(self.dev)
        abs_time = torch.from_numpy(np.arange(idx, idx + self.ctx_win_len) * self.resolution).unsqueeze(1).float().to(
            self.dev)
        if (self.num_time_indx == 2):  
            out = torch.cat((rel_time, abs_time, self.scaled[idx: idx + self.ctx_win_len, :]), -1).unsqueeze(0)
        if (self.num_time_indx == 1):  
            out = torch.cat((rel_time, self.scaled[idx: idx + self.ctx_win_len, :]), -1).unsqueeze(0)
        if (self.num_time_indx == 0):  
            out = self.scaled[idx: idx + self.ctx_win_len, :].unsqueeze(0)
        return torch.squeeze(out, 0)
    def get_train_test_samplers(self, train_test_split):
        indices = list(range(self.dataset_size))
        split = int(np.floor(train_test_split * self.dataset_size))
        train_indices, test_indices = indices[: split - self.ctx_win_len], indices[split-self.ctx_win_len: ]
        return SubsetRandomSampler(train_indices), SubsetRandomSampler(test_indices)
    def plot_corr(self, df, size=10):
        corr = df.corr()
        fig, ax = plt.subplots(figsize=(size, size))
        ax.matshow(corr)
        plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
        plt.yticks(range(len(corr.columns)), corr.columns)

# %%
class Test_pre(MyDataset):
    def __init__(self, csv_file, dev, ctx_win_len, num_time_indx=1):
        self.num_time_indx = num_time_indx
        self.dev = dev
        df = read_csv('dataset/test1.csv',index_col=0)
        self.ctx_win_len = ctx_win_len
        values = df.values
        values = values.astype('float32')
        self.scaled = values
        self.dataset_size = self.scaled.shape[0]
        self.scaled = torch.from_numpy(self.scaled).float().to(dev)
        self.resolution = 1

# %%
params = _params_
dataset = Test_pre(csv_file=params['data_file'], dev=device, ctx_win_len=params['ctx_win_len'], num_time_indx=params['num_time_idx'])

# %%
'''
dataset = electricity_pre(csv_file=params['data_file'], dev=device, ctx_win_len=params['ctx_win_len'], num_time_indx=params['num_time_idx'])
'''
# Out:
# "\ndataset = electricity_pre(csv_file=params['data_file'], dev=device, ctx_win_len=params['ctx_win_len'], num_time_indx=params['num_time_idx'])\n"

# %%
num_covariates = params['num_covariates']
num_time_idx = params['num_time_idx']
num_targets = params['num_targets']
input_dim = num_time_idx + num_targets + num_covariates
'''
Size of the entire context window utilized during training
can be divided into 2 sections - first: conditioning context with input data points and network predictions conditioned on real data; 
and other one is  prediction context, where network predictions are conditioned on network output from the ealrier steps.
'''
ctx_win_len = params['ctx_win_len']
cond_win_len = params['cond_win_len']
pred_win_len = ctx_win_len - cond_win_len - 1
batch_size = params['batch_size']

# %%
model = model(num_lstms=params['num_lstms'], input_dim=input_dim, output_dim=params['num_targets'],hidden_dim=params['hidden_dim']).to(device)
optimizer = optim.Adam(model.parameters(), params['lr'])
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=params['lr_step_size'], gamma=params['lr_gamma'])

# %%
train_sampler, test_sampler = dataset.get_train_test_samplers(params['train_test_split'])
train_dataloader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, shuffle=False, num_workers=0)
test_dataloader = DataLoader(dataset, batch_size=1, sampler=test_sampler,shuffle=False, num_workers=0)
max_batches_per_epoch = params['max_batches_per_epoch']
num_epochs = params['num_epochs']

# %%
losses = []
batch_num = 1
utils = utils(device, params)
# Trainin loop
def train():
    for epoch in range(0, num_epochs):
        batch_num = 0
        for i, batch in enumerate(train_dataloader):
            if batch_num > max_batches_per_epoch:
                break    
            input, target, covariates = utils.split_batch(batch) #splitting batches : issue with sequence
            #conditioning window input,Prediction window , model op conditioned on previous values
            # model output for the previous step
            input_cond = input[:, 0:cond_win_len, :]
            input_cond, covariates = utils.scale(input_cond, covariates)
            optimizer.zero_grad()
            #forward pass
            out = model(input_cond, covariates, future=pred_win_len)
            out = utils.invert_scale(out, probabalistic=True)
            #rescale
            loss = model.NLL(out, target)
            #loss calc
            loss.backward()
            scheduler.step()
            optimizer.step()
            loss = loss.item()
            losses.append(loss)
            print(f"epoch:{epoch} /{num_epochs}| batch:{batch_num}:loss:{loss}")
            batch_num = batch_num + 1
    return model, losses

# %%
model, losses = train()
data='elec'# electricity dataset
date_=str(now).replace(" ", "")
model_save_ = f"{data}_epochs{params['num_epochs']}_{ date_ }"
torch.save(model.state_dict(), model_save_+".pth")
# Out:
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 0
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:0 /100| batch:0:loss:5.554049491882324
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 1
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:0 /100| batch:1:loss:5.45492696762085
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 2
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:0 /100| batch:2:loss:5.1623382568359375
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 3
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:0 /100| batch:3:loss:5.245424270629883
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 4
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:0 /100| batch:4:loss:5.428194046020508
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 5
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:0 /100| batch:5:loss:5.147431373596191
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 6
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:1 /100| batch:0:loss:5.284180164337158
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 7
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:1 /100| batch:1:loss:5.271726608276367
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 8
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:1 /100| batch:2:loss:5.195893287658691
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 9
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:1 /100| batch:3:loss:5.312349319458008
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 10
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:1 /100| batch:4:loss:5.311243057250977
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 11
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:1 /100| batch:5:loss:5.478202819824219
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 12
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:2 /100| batch:0:loss:5.325037479400635
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 13
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:2 /100| batch:1:loss:5.431184768676758
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 14
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:2 /100| batch:2:loss:5.051304817199707
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 15
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:2 /100| batch:3:loss:5.111929893493652
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 16
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:2 /100| batch:4:loss:5.15126895904541
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 17
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:2 /100| batch:5:loss:5.559280872344971
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 18
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:3 /100| batch:0:loss:5.232892990112305
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 19
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:3 /100| batch:1:loss:5.2777886390686035
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 20
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:3 /100| batch:2:loss:5.074167251586914
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 21
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:3 /100| batch:3:loss:5.317657470703125
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 22
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:3 /100| batch:4:loss:5.124378204345703
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 23
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:3 /100| batch:5:loss:4.962711334228516
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 24
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:4 /100| batch:0:loss:5.089919090270996
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 25
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:4 /100| batch:1:loss:5.041286945343018
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 26
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:4 /100| batch:2:loss:4.9907636642456055
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 27
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:4 /100| batch:3:loss:4.94802713394165
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 28
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:4 /100| batch:4:loss:5.225873947143555
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 29
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:4 /100| batch:5:loss:4.973428726196289
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 30
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:5 /100| batch:0:loss:5.024688720703125
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 31
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:5 /100| batch:1:loss:4.872298240661621
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 32
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:5 /100| batch:2:loss:5.1589202880859375
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 33
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:5 /100| batch:3:loss:4.841274261474609
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 34
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:5 /100| batch:4:loss:4.8863019943237305
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 35
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:5 /100| batch:5:loss:4.974226951599121
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 36
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:6 /100| batch:0:loss:4.8148088455200195
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 37
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:6 /100| batch:1:loss:4.757576942443848
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 38
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:6 /100| batch:2:loss:4.764470100402832
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 39
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:6 /100| batch:3:loss:4.886397361755371
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 40
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:6 /100| batch:4:loss:4.832571029663086
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 41
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:6 /100| batch:5:loss:5.012392044067383
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 42
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:7 /100| batch:0:loss:6.6539411544799805
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 43
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:7 /100| batch:1:loss:4.6880059242248535
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 44
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:7 /100| batch:2:loss:4.503083229064941
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 45
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:7 /100| batch:3:loss:5.1021013259887695
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 46
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:7 /100| batch:4:loss:4.694214344024658
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 47
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:7 /100| batch:5:loss:5.283083438873291
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 48
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:8 /100| batch:0:loss:5.075787544250488
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 49
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:8 /100| batch:1:loss:4.825874328613281
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 50
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:8 /100| batch:2:loss:5.026998519897461
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 51
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:8 /100| batch:3:loss:4.968583583831787
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 52
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:8 /100| batch:4:loss:5.046473503112793
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 53
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:8 /100| batch:5:loss:4.919068336486816
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 54
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:9 /100| batch:0:loss:4.839552879333496
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 55
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:9 /100| batch:1:loss:5.097825050354004
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 56
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:9 /100| batch:2:loss:4.9038591384887695
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 57
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:9 /100| batch:3:loss:5.067605018615723
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 58
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:9 /100| batch:4:loss:5.077371597290039
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 59
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:9 /100| batch:5:loss:5.034386157989502
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 60
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:10 /100| batch:0:loss:5.117281913757324
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 61
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:10 /100| batch:1:loss:5.032704830169678
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 62
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:10 /100| batch:2:loss:5.138457298278809
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 63
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:10 /100| batch:3:loss:4.8934221267700195
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 64
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:10 /100| batch:4:loss:4.8652873039245605
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 65
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:10 /100| batch:5:loss:4.882604598999023
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 66
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:11 /100| batch:0:loss:4.919528007507324
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 67
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:11 /100| batch:1:loss:5.171080589294434
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 68
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:11 /100| batch:2:loss:4.74691104888916
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 69
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:11 /100| batch:3:loss:4.965360164642334
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 70
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:11 /100| batch:4:loss:4.965397834777832
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 71
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:11 /100| batch:5:loss:5.10490608215332
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 72
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:12 /100| batch:0:loss:4.766634464263916
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 73
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:12 /100| batch:1:loss:4.788600444793701
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 74
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:12 /100| batch:2:loss:4.817158222198486
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 75
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:12 /100| batch:3:loss:5.076033592224121
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 76
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:12 /100| batch:4:loss:4.938389778137207
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 77
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:12 /100| batch:5:loss:5.083103656768799
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 78
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:13 /100| batch:0:loss:4.993260383605957
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 79
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:13 /100| batch:1:loss:4.676881790161133
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 80
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:13 /100| batch:2:loss:4.669220924377441
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 81
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:13 /100| batch:3:loss:4.603649616241455
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 82
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:13 /100| batch:4:loss:4.7910990715026855
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 83
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:13 /100| batch:5:loss:5.182250022888184
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 84
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:14 /100| batch:0:loss:4.318316459655762
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 85
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:14 /100| batch:1:loss:4.983698844909668
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 86
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:14 /100| batch:2:loss:4.941701889038086
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 87
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:14 /100| batch:3:loss:5.176313400268555
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 88
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:14 /100| batch:4:loss:4.910614967346191
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 89
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:14 /100| batch:5:loss:5.370450973510742
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 90
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:15 /100| batch:0:loss:5.27194356918335
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 91
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:15 /100| batch:1:loss:5.245558261871338
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 92
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:15 /100| batch:2:loss:5.125430107116699
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 93
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:15 /100| batch:3:loss:4.951095104217529
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 94
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:15 /100| batch:4:loss:5.289801597595215
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 95
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:15 /100| batch:5:loss:5.219880104064941
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 96
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:16 /100| batch:0:loss:5.159395217895508
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 97
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:16 /100| batch:1:loss:5.23919677734375
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 98
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:16 /100| batch:2:loss:4.987274646759033
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 99
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:16 /100| batch:3:loss:4.9486894607543945
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 100
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:16 /100| batch:4:loss:5.185376167297363
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 101
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:16 /100| batch:5:loss:5.2370758056640625
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 102
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:17 /100| batch:0:loss:5.07319450378418
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 103
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:17 /100| batch:1:loss:5.00327205657959
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 104
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:17 /100| batch:2:loss:4.986557960510254
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 105
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:17 /100| batch:3:loss:5.223587989807129
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 106
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:17 /100| batch:4:loss:5.054478168487549
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 107
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:17 /100| batch:5:loss:5.041814804077148
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 108
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:18 /100| batch:0:loss:5.105452537536621
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 109
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:18 /100| batch:1:loss:5.066347122192383
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 110
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:18 /100| batch:2:loss:4.975654602050781
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 111
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:18 /100| batch:3:loss:4.9454803466796875
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 112
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:18 /100| batch:4:loss:5.092076301574707
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 113
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:18 /100| batch:5:loss:5.175318717956543
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 114
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:19 /100| batch:0:loss:5.131128787994385
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 115
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:19 /100| batch:1:loss:4.906521797180176
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 116
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:19 /100| batch:2:loss:5.076387405395508
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 117
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:19 /100| batch:3:loss:4.961152076721191
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 118
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:19 /100| batch:4:loss:5.019180774688721
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 119
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:19 /100| batch:5:loss:5.2780537605285645
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 120
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:20 /100| batch:0:loss:4.731914520263672
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 121
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:20 /100| batch:1:loss:5.149710655212402
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 122
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:20 /100| batch:2:loss:5.200436592102051
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 123
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:20 /100| batch:3:loss:5.023547172546387
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 124
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:20 /100| batch:4:loss:5.005247116088867
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 125
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:20 /100| batch:5:loss:5.0962982177734375
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 126
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:21 /100| batch:0:loss:5.231266021728516
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 127
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:21 /100| batch:1:loss:4.878322124481201
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 128
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:21 /100| batch:2:loss:4.900905609130859
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 129
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:21 /100| batch:3:loss:4.979273796081543
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 130
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:21 /100| batch:4:loss:5.03781795501709
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 131
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:21 /100| batch:5:loss:5.076145172119141
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 132
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:22 /100| batch:0:loss:4.812135696411133
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 133
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:22 /100| batch:1:loss:5.087841033935547
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 134
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:22 /100| batch:2:loss:5.020534515380859
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 135
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:22 /100| batch:3:loss:5.147907257080078
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 136
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:22 /100| batch:4:loss:4.985385894775391
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 137
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:22 /100| batch:5:loss:4.764142990112305
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 138
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:23 /100| batch:0:loss:4.989516735076904
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 139
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:23 /100| batch:1:loss:5.05973482131958
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 140
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:23 /100| batch:2:loss:4.83660888671875
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 141
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:23 /100| batch:3:loss:4.998465061187744
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 142
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:23 /100| batch:4:loss:5.041451454162598
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 143
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:23 /100| batch:5:loss:4.742858409881592
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 144
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:24 /100| batch:0:loss:4.9598846435546875
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 145
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:24 /100| batch:1:loss:4.893923759460449
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 146
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:24 /100| batch:2:loss:4.852531433105469
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 147
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:24 /100| batch:3:loss:5.068877220153809
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 148
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:24 /100| batch:4:loss:4.85477352142334
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 149
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:24 /100| batch:5:loss:4.979274749755859
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 150
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:25 /100| batch:0:loss:5.025329113006592
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 151
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:25 /100| batch:1:loss:4.893506050109863
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 152
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:25 /100| batch:2:loss:4.6938982009887695
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 153
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:25 /100| batch:3:loss:4.9578776359558105
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 154
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:25 /100| batch:4:loss:4.786776065826416
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 155
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:25 /100| batch:5:loss:5.020788669586182
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 156
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:26 /100| batch:0:loss:5.013225555419922
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 157
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:26 /100| batch:1:loss:4.852909088134766
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 158
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:26 /100| batch:2:loss:4.836823463439941
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 159
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:26 /100| batch:3:loss:4.634105682373047
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 160
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:26 /100| batch:4:loss:4.636986255645752
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 161
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:26 /100| batch:5:loss:4.888178825378418
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 162
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:27 /100| batch:0:loss:4.725508689880371
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 163
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:27 /100| batch:1:loss:4.690378189086914
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 164
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:27 /100| batch:2:loss:4.655824661254883
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 165
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:27 /100| batch:3:loss:4.543526649475098
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 166
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:27 /100| batch:4:loss:4.710660457611084
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 167
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:27 /100| batch:5:loss:4.863420009613037
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 168
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:28 /100| batch:0:loss:4.678340911865234
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 169
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:28 /100| batch:1:loss:4.623847961425781
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 170
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:28 /100| batch:2:loss:4.565984725952148
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 171
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:28 /100| batch:3:loss:4.749149322509766
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 172
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:28 /100| batch:4:loss:4.678584098815918
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 173
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:28 /100| batch:5:loss:4.374118328094482
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 174
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:29 /100| batch:0:loss:4.402261257171631
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 175
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:29 /100| batch:1:loss:4.187014102935791
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 176
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:29 /100| batch:2:loss:4.580569267272949
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 177
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:29 /100| batch:3:loss:4.8951945304870605
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 178
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:29 /100| batch:4:loss:4.090723037719727
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 179
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:29 /100| batch:5:loss:5.158541679382324
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 180
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:30 /100| batch:0:loss:4.529820919036865
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 181
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:30 /100| batch:1:loss:4.6104888916015625
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 182
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:30 /100| batch:2:loss:4.4612345695495605
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 183
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:30 /100| batch:3:loss:4.511033058166504
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 184
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:30 /100| batch:4:loss:4.271404266357422
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 185
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:30 /100| batch:5:loss:3.938075542449951
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 186
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:31 /100| batch:0:loss:4.210886001586914
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 187
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:31 /100| batch:1:loss:4.5106329917907715
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 188
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:31 /100| batch:2:loss:4.410595893859863
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 189
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:31 /100| batch:3:loss:3.9703493118286133
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 190
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:31 /100| batch:4:loss:4.411859512329102
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 191
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:31 /100| batch:5:loss:4.27915096282959
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 192
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# ...
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:89 /100| batch:2:loss:1.5058690309524536
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 537
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:89 /100| batch:3:loss:1.0770812034606934
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 538
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:89 /100| batch:4:loss:1.4606571197509766
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 539
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:89 /100| batch:5:loss:1.2278268337249756
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 540
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:90 /100| batch:0:loss:1.2171342372894287
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 541
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:90 /100| batch:1:loss:1.2196989059448242
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 542
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:90 /100| batch:2:loss:1.178282380104065
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 543
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:90 /100| batch:3:loss:1.2288272380828857
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 544
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:90 /100| batch:4:loss:1.3977751731872559
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 545
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:90 /100| batch:5:loss:1.1581956148147583
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 546
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:91 /100| batch:0:loss:1.274905800819397
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 547
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:91 /100| batch:1:loss:1.2812767028808594
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 548
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:91 /100| batch:2:loss:1.253093957901001
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 549
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:91 /100| batch:3:loss:1.3327330350875854
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 550
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:91 /100| batch:4:loss:1.1991451978683472
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 551
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:91 /100| batch:5:loss:1.261275291442871
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 552
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:92 /100| batch:0:loss:1.2152628898620605
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 553
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:92 /100| batch:1:loss:1.3083267211914062
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 554
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:92 /100| batch:2:loss:1.147127628326416
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 555
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:92 /100| batch:3:loss:1.215169906616211
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 556
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:92 /100| batch:4:loss:1.3746068477630615
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 557
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:92 /100| batch:5:loss:1.1014267206192017
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 558
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:93 /100| batch:0:loss:1.1903769969940186
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 559
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:93 /100| batch:1:loss:1.1085443496704102
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 560
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:93 /100| batch:2:loss:1.3453171253204346
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 561
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:93 /100| batch:3:loss:1.2378449440002441
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 562
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:93 /100| batch:4:loss:1.2442259788513184
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 563
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:93 /100| batch:5:loss:1.2592475414276123
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 564
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:94 /100| batch:0:loss:1.1318964958190918
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 565
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:94 /100| batch:1:loss:1.2273621559143066
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 566
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:94 /100| batch:2:loss:1.2792730331420898
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 567
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:94 /100| batch:3:loss:1.564849853515625
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 568
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:94 /100| batch:4:loss:1.1796338558197021
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 569
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:94 /100| batch:5:loss:1.0857582092285156
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 570
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:95 /100| batch:0:loss:1.638437032699585
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 571
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:95 /100| batch:1:loss:1.0929811000823975
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 572
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:95 /100| batch:2:loss:1.3808956146240234
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 573
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:95 /100| batch:3:loss:1.4967048168182373
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 574
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:95 /100| batch:4:loss:1.1720259189605713
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 575
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:95 /100| batch:5:loss:1.1823241710662842
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 576
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:96 /100| batch:0:loss:1.325966477394104
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 577
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:96 /100| batch:1:loss:1.1310795545578003
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 578
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:96 /100| batch:2:loss:1.2170867919921875
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 579
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:96 /100| batch:3:loss:1.1415694952011108
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 580
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:96 /100| batch:4:loss:1.1701774597167969
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 581
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:96 /100| batch:5:loss:1.2267532348632812
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 582
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:97 /100| batch:0:loss:1.271406888961792
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 583
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:97 /100| batch:1:loss:1.1421130895614624
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 584
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:97 /100| batch:2:loss:1.1368024349212646
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 585
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:97 /100| batch:3:loss:1.185642957687378
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 586
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:97 /100| batch:4:loss:1.3447444438934326
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 587
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:97 /100| batch:5:loss:1.0336638689041138
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 588
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:98 /100| batch:0:loss:1.1615055799484253
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 589
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:98 /100| batch:1:loss:1.2463786602020264
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 590
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:98 /100| batch:2:loss:1.0859886407852173
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 591
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:98 /100| batch:3:loss:1.3933649063110352
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 592
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:98 /100| batch:4:loss:1.2361290454864502
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 593
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:98 /100| batch:5:loss:1.0992447137832642
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 594
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:99 /100| batch:0:loss:1.2463674545288086
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 595
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:99 /100| batch:1:loss:1.317455768585205
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 596
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:99 /100| batch:2:loss:1.1330047845840454
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 597
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:99 /100| batch:3:loss:1.3769595623016357
# torch.Size([32, 79, 7, 2]) torch.Size([32, 79, 7])
# 598
# ........NLL.........
# squeeze torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 7]) torch.Size([32, 79, 7])
# torch.Size([32, 79, 4])
# epoch:99 /100| batch:4:loss:1.2564888000488281
# torch.Size([15, 79, 7, 2]) torch.Size([15, 79, 7])
# 599
# ........NLL.........
# squeeze torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 7]) torch.Size([15, 79, 7])
# torch.Size([15, 79, 4])
# epoch:99 /100| batch:5:loss:1.2800674438476562

# %%
model
# Out:
# model(
#   (lstms): ModuleList(
#     (0): LSTMCell(7, 64)
#     (1): LSTMCell(64, 64)
#   )
#   (mean): Linear(in_features=64, out_features=7, bias=True)
#   (std): Linear(in_features=64, out_features=7, bias=True)
# )

# %%
test_dataloader_iter = iter(test_dataloader)
for i in range(0, 1):
    test_batch = next(test_dataloader_iter)
    with torch.no_grad():
        input, target, covariates = utils.split_batch(test_batch)
        input, covariates = utils.scale(input, covariates)
        pred = model(input[:, 0:cond_win_len, :], covariates, future=pred_win_len)
        pred = utils.invert_scale(pred, True)
        loss = model.NLL(pred, target)
        print("loss (prediction): {0}".format(loss))
        preds = pred[0, :, :, :].detach().cpu().numpy()
        targets = target[0, :, :].detach().cpu().numpy()
        preds[:, 4:5, 0]=np.sum(preds[:, 0:2, 0:1],axis=1)
        preds[:, 4:5, 1]=np.sum(preds[:, 0:2, 1:2],axis=1)
        preds[:, 5:6, 0]=np.sum(preds[:, 2:4, 0:1],axis=1)
        preds[:, 5:6, 1]=np.sum(preds[:, 2:4, 1:2],axis=1)
        preds[:, 6:7, 0]=np.sum(preds[:, 4:6, 0:1],axis=1)
        preds[:, 6:7, 1]=np.sum(preds[:, 4:6, 1:2],axis=1)
    for j in range(num_targets):
        pred = preds[:, j, 0]  
        std = preds[:, j, 1]  
        target = targets[:, j]
        plt.figure()

        plt.xlabel('x')
        plt.ylabel('y')
        plt.xticks()
        plt.yticks()
        plt.plot(np.arange(len(target)), target, 'r', linewidth=2.0)
        plt.plot(np.arange(cond_win_len), pred[0:cond_win_len], 'b', linewidth=2.0)
        plt.plot(np.arange(cond_win_len, cond_win_len + pred_win_len), pred[cond_win_len:], 'g' + ':',
                 linewidth=2.0)
        plt.fill_between(np.arange(len(target)), pred - std, pred + std, color='cyan', alpha=0.5)
        plt.fill_between(np.arange(len(target)), pred - 2 * std, pred + 2 * std, color='cyan', alpha=0.2)
# Out:
# torch.Size([1, 79, 7, 2]) torch.Size([1, 79, 7])
# 600
# ........NLL.........
# squeeze torch.Size([1, 79, 7]) torch.Size([1, 79, 7])
# torch.Size([1, 79, 7]) torch.Size([1, 79, 7])
# torch.Size([1, 79, 4])
# loss (prediction): 4.724458694458008

# %% [markdown]
# np.array([1]).dtype

# %% [markdown]
# tt=GC[0][0]

# %% [markdown]
# tt[:, :, 0:2].shape

# %% [markdown]
# If you have an image x with shape C x H x W and want to compute the average pixel intensity value per channel you could do:
#
# avg = torch.sum(x, dim=(1,2)) / (H*W)

# %% [markdown]
# tt[:, :, 0:3]

# %% [markdown]
# tt[:, :, 1:2]

# %% [markdown]
# (torch.sum(tt[:, :, 0:2], axis=2)).reshape(tt[:, :, 1:2].shape)
