# %%
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
from matplotlib import pyplot as plt
import datetime as dt
from torch.utils.data.dataloader import DataLoader
from datetime import datetime
from dataset.electricity_dataset import electricity_pre
from pandas import read_csv
import pandas
from datetime import datetime
import os
from matplotlib import pyplot
import warnings
from pandas import read_csv, DataFrame
import os
import torch
from pandas import read_csv
from datetime import datetime
import os
from matplotlib import pyplot
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import LabelEncoder
from torch.utils.data.dataset import Dataset
from torch.utils.data.dataloader import DataLoader
from torch.utils.data.sampler import Sampler, SubsetRandomSampler
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
gc =0

# %%
import random
np.set_printoptions(precision=4)
#array_=np.random.random_sample((365,2))
array_ = np.sin((np.arange(365)/10+3*np.random.random_sample(2).reshape(-1,1)).T)+np.random.random_sample((365,2))
fnl_=np.concatenate([array_, array_.sum(1)[:,None]], -1)

# %%
fnl_.shape
# Out:
# (365, 3)

# %%
start_date = dt.date(2021, 1, 1)
end_date   = dt.date(2022, 1, 1)
dates_ = [ start_date + dt.timedelta(n) for n in range(int ((end_date - start_date).days))]

# %%
dts=[]
for i in dates_ :
    dts.append(i.strftime("%Y-%m-%d"))

# %%
array_.shape
# Out:
# (365, 2)

# %%
#np.array(dts)

# %%
import pandas as pd

# %%
df = pd.DataFrame(fnl_, columns = ['1','2','3'])

# %%
df['date'] = pd.Series(np.array(dts), index=df.index)

# %%
df.set_index("date", inplace=True)

# %%
df
# Out:
#                    1         2         3
# date
# 2021-01-01  1.838297  1.509692  3.347989
# 2021-01-02  1.588492  1.249444  2.837936
# 2021-01-03  1.236640  1.296903  2.533543
# 2021-01-04  1.671535  0.797909  2.469444
# 2021-01-05  1.184459  0.779321  1.963780
# ...              ...       ...       ...
# 2021-12-27 -0.215168  0.621722  0.406553
# 2021-12-28  0.061260  1.110540  1.171799
# 2021-12-29 -0.091670  1.083370  0.991699
# 2021-12-30  0.117719  1.508938  1.626657
# 2021-12-31  0.896698  1.303618  2.200316
#
# [365 rows x 3 columns]

# %%
warnings.filterwarnings('ignore')
now = datetime.now()
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
GC=[]

# %%
#  probabalistic model with likelihood function
class model(nn.Module):
    def __init__(self, num_lstms, input_dim, output_dim=1, hidden_dim=64):
        super(model, self).__init__()
        self.lstm_out = hidden_dim
        self.num_lstms = num_lstms
        lstms = []
        
        lstms.append(nn.LSTMCell(input_dim, self.lstm_out))
        for i in range(1, self.num_lstms):
            lstms.append(nn.LSTMCell(self.lstm_out, self.lstm_out))
        self.lstms = nn.ModuleList(lstms)
        # μ and σ  distibution -> next point for every t_i.prediction length is from output dimensions
        self.mean = nn.Linear(self.lstm_out, output_dim)
        self.std = nn.Linear(self.lstm_out, output_dim)

    def forward(self, input, covariates, future = 0):
        dev = input.device
        means = torch.Tensor().to(dev)
        stds = torch.Tensor().to(dev)
        outputs = []
        h_t = []
        c_t = []
        cond_ctx_len = input.size(1)
        pred_ctx_len = future
        #for covariartes concat input and covariates
        if covariates.shape[2] != 0:
            input = torch.cat((input, covariates[:, 0:cond_ctx_len, :]), 2)
        for i in range(0, self.num_lstms):
            h_t.append(torch.zeros(input.size(0), self.lstm_out, dtype=torch.float).to(dev))
            c_t.append(torch.zeros(input.size(0), self.lstm_out, dtype=torch.float).to(dev))
        '''
         h(hidden state),c(cell state)-> output of Lstm cell, h(i)-> passed to lstm(i+1) cell, 
         h(i) and c(i) are recurrent for lstm cell(i+1) 
         and the output from previous cell '''
        for i, input_t in enumerate(input.chunk(input.size(1), dim=1)):
            h_t[0], c_t[0] = self.lstms[0](input_t.squeeze(1), (h_t[0], c_t[0])) #first cell ->concat of input and covariates, recurrent input 
            for n in range(1, self.num_lstms):
                h_t[n], c_t[n] = self.lstms[n](h_t[n - 1], (h_t[n], c_t[n]))#susquent cells-> prev. output from stack, recurrent input
            mean = self.mean(h_t[n])
            std = self.std(h_t[n])
            means = torch.cat((means, mean.unsqueeze(1)), 1)
            stds = torch.cat((stds, std.unsqueeze(1)), 1)
        stds = self.softplus(stds)
        for i in range(future):
            output_t = torch.cat((mean, covariates[:, cond_ctx_len + i, :]), 1)
            h_t[0], c_t[0] = self.lstms[0](output_t, (h_t[0], c_t[0]))
            for n in range(1, self.num_lstms):
                h_t[n], c_t[n] = self.lstms[n](h_t[n - 1], (h_t[n], c_t[n]))
            mean = self.mean(h_t[n])
            std = self.std(h_t[n])
            std = self.softplus(std) # avoid infinties
            means = torch.cat((means, mean.unsqueeze(1)), 1)
            stds = torch.cat((stds, std.unsqueeze(1)), 1)
        means = means.unsqueeze(-1)
        stds = stds.unsqueeze(-1)
        outputs = torch.cat((means, stds), -1)
        return outputs

    def sample(self, mean, std):

        normal_dist = torch.distributions.normal.Normal(mean, std)
        return normal_dist.sample()

    def softplus(self, x):
        softplus = torch.log(1+torch.exp(x))
        softplus = torch.where(softplus==float('inf'), x, softplus)
        return softplus

    def NLL(self, outputs, truth):#negative log liklihood
        print(outputs.shape,truth.shape)
        mean, std = torch.split(outputs, 1, dim=3)
        #print('normal',mean.shape,std.shape)
        global gc
        #print(outputs,truth)
        print(gc)
        gc=gc+1
        print(f"{'NLL':.^20}")
        mean = mean.squeeze(3)
        std = std.squeeze(3)
        print('squeeze',mean.shape,std.shape)
        
        print(mean.shape,truth.shape)
        global GC   
        GC.append([mean,truth])
        diff = torch.sub(truth[:, :, :2], mean[:, :, :2])
        
        print(diff.shape)        
        loss = torch.mean(torch.div(torch.pow(diff, 2), torch.pow(std[:, :, :2], 2))) + 2*torch.mean(torch.log(std[:, :, :2])) + \
                                torch.mean(torch.abs(torch.sub(truth[:, :,2:3],mean[:, :, 0:1]+ mean[:, :, 1:2])))
        #print('loss',loss.shape)
        return loss

# %%
def date_cv(x):
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

# %%
_params_ = {'lr': 0.0001,
    'lr_step_size': 1000,
    'lr_gamma': 1,
    'ctx_win_len': 192,
    'cond_win_len': 168,
    'batch_size': 32,
    'num_covariates': 0,
    'total_num_covariates': 0,
    'num_time_idx': 0,
    'num_targets': 3,
    'total_num_targets': 3,
    'num_lstms': 2,
    'hidden_dim': 64,
    'max_batches_per_epoch': 200,
    'num_epochs': 100,
    'data_file': 'test.csv',
    'train_test_split': 0.7
}

ls_params = _params_
ls_params['num_covariates'] = 0

# %%
class utils:
    def __init__(self, dev,_params):
        self.min = 0
        self.max = 0
        self.range = 0
        self.mean = 0
        self.dev = dev
        self._params = _params

    def NRMSE(self, input, target):
        return np.sqrt(torch.nn.functional.mse_loss(input, target).item()) / torch.mean(torch.abs(target))

    def NormDeviation(self, input, target):
        return torch.mean(torch.abs(input - target)) / torch.mean(torch.abs(target))

    def MAE(self, input, target):
        return torch.mean(torch.abs(input - target))

    def split_batch(self, batch):
        num_time_idx = self._params['num_time_idx']
        num_targets = self._params['num_targets']
        total_num_targets = self._params['total_num_targets']
        num_covariates = self._params['num_covariates']    
        b = num_time_idx
        time_idx = batch[:, 1::, :b].to(self.dev).float()
        e = b + num_targets
        input = batch[:, 0:-1, b: e].to(self.dev).float()
        target = batch[:, 1::, b: e].to(self.dev).float()
        e = e - num_targets + total_num_targets
        total_num_covariates = batch.shape[2] - e + 1  
        covariates = time_idx
        b = e
        e = b + num_covariates
        if (num_covariates > 0):
            covariates = torch.cat((time_idx, batch[:, 1::, b: e]), -1)
        return input, target, covariates

    def scale(self, input, covariates):
        
        self.mean = torch.mean(input, dim=1).unsqueeze(1)
        input = input - self.mean
        min = torch.min(input, dim=1)[0].unsqueeze(1)
        max = torch.max(input, dim=1)[0].unsqueeze(1)
        self.range = max - min
        self.range[self.range < 1e-5] = 1e-5
        input = input / self.range

        num_covariates = self._params['num_covariates']
        if (num_covariates > 0):
            mean = torch.mean(covariates, dim=1).unsqueeze(1)
            covariates = covariates - mean
            min = torch.min(covariates, dim=1)[0].unsqueeze(1)
            max = torch.max(covariates, dim=1)[0].unsqueeze(1)
            range = max - min
            range[range < 1e-5] = 1e-5
            covariates = covariates / range
        return input, covariates

    def invert_scale(self, input, probabalistic=False):
        if probabalistic == False:
            return input * self.range + self.mean
        else:
            mean = input[:, :, :, 0]
            std = input[:, :, :, 1]
            scaled_mean = mean * self.range + self.mean
            scaled_std = std * torch.sqrt(self.range)
            return torch.cat((scaled_mean.unsqueeze(-1), scaled_std.unsqueeze(-1)), -1)

# %%
'''
dataset = read_csv('dataset/elec.txt', sep=";", decimal=",", header=None, skiprows=[0], parse_dates = [[0]], date_parser=date_cv)
dataset.set_index("0", inplace=True)
weekday = pandas.Series(dataset.index[:].weekday, dtype='int32')
hour = pandas.Series(dataset.index[:].hour, dtype='int32')
minute = pandas.Series(dataset.index[:].minute, dtype='int32')
dataset.insert(len(dataset.columns), 'weekday', weekday.values)
dataset.insert(len(dataset.columns), 'hour', hour.values)
dataset.insert(len(dataset.columns), 'min', minute.values)
dataset.index.name = 'date'
dataset = dataset[35042:]
print(dataset.head(5))
'''
# Out:
# '\ndataset = read_csv(\'dataset/elec.txt\', sep=";", decimal=",", header=None, skiprows=[0], parse_dates = [[0]], date_parser=date_cv)\ndataset.set_index("0", inplace=True)\nweekday = pandas.Series(dataset.index[:].weekday, dtype=\'int32\')\nhour = pandas.Series(dataset.index[:].hour, dtype=\'int32\')\nminute = pandas.Series(dataset.index[:].minute, dtype=\'int32\')\ndataset.insert(len(dataset.columns), \'weekday\', weekday.values)\ndataset.insert(len(dataset.columns), \'hour\', hour.values)\ndataset.insert(len(dataset.columns), \'min\', minute.values)\ndataset.index.name = \'date\'\ndataset = dataset[35042:]\nprint(dataset.head(5))\n'

# %%
df.dtypes
# Out:
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
df
# Out:
#                    1         2         3
# date
# 2021-01-01  1.838297  1.509692  3.347989
# 2021-01-02  1.588492  1.249444  2.837936
# 2021-01-03  1.236640  1.296903  2.533543
# 2021-01-04  1.671535  0.797909  2.469444
# 2021-01-05  1.184459  0.779321  1.963780
# ...              ...       ...       ...
# 2021-12-27 -0.215168  0.621722  0.406553
# 2021-12-28  0.061260  1.110540  1.171799
# 2021-12-29 -0.091670  1.083370  0.991699
# 2021-12-30  0.117719  1.508938  1.626657
# 2021-12-31  0.896698  1.303618  2.200316
#
# [365 rows x 3 columns]

# %%
df.to_csv('dataset/test.csv')

# %%
#for 
values = df.values
groups = [0, 1, 2]
i = 1
fig = pyplot.figure()
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[1:400, group])
    pyplot.title(df.columns[group], y=0, loc='right')
    i += 1
fig.subplots_adjust(hspace=0.5)
pyplot.show()

# %%
class MyDataset(Dataset):
    def __len__(self):
        return self.dataset_size
    def __getitem__(self, idx):
        rel_time = torch.from_numpy(np.arange(0, self.ctx_win_len) * self.resolution).unsqueeze(1).float().to(self.dev)
        abs_time = torch.from_numpy(np.arange(idx, idx + self.ctx_win_len) * self.resolution).unsqueeze(1).float().to(
            self.dev)
        if (self.num_time_indx == 2):  
            out = torch.cat((rel_time, abs_time, self.scaled[idx: idx + self.ctx_win_len, :]), -1).unsqueeze(0)
        if (self.num_time_indx == 1):  
            out = torch.cat((rel_time, self.scaled[idx: idx + self.ctx_win_len, :]), -1).unsqueeze(0)
        if (self.num_time_indx == 0):  
            out = self.scaled[idx: idx + self.ctx_win_len, :].unsqueeze(0)
        return torch.squeeze(out, 0)
    def get_train_test_samplers(self, train_test_split):
        indices = list(range(self.dataset_size))
        split = int(np.floor(train_test_split * self.dataset_size))
        train_indices, test_indices = indices[: split - self.ctx_win_len], indices[split: -self.ctx_win_len]
        return SubsetRandomSampler(train_indices), SubsetRandomSampler(test_indices)
    def plot_corr(self, df, size=10):
        corr = df.corr()
        fig, ax = plt.subplots(figsize=(size, size))
        ax.matshow(corr)
        plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
        plt.yticks(range(len(corr.columns)), corr.columns)

# %%
class Test_pre(MyDataset):
    def __init__(self, csv_file, dev, ctx_win_len, num_time_indx=1):
        self.num_time_indx = num_time_indx
        self.dev = dev
        df = read_csv('dataset/test.csv',index_col=0)
        self.ctx_win_len = ctx_win_len
        values = df.values
        values = values.astype('float32')
        self.scaled = values
        self.dataset_size = self.scaled.shape[0]
        self.scaled = torch.from_numpy(self.scaled).float().to(dev)
        self.resolution = 1

# %%
params = _params_
dataset = Test_pre(csv_file=params['data_file'], dev=device, ctx_win_len=params['ctx_win_len'], num_time_indx=params['num_time_idx'])

# %%
'''
dataset = electricity_pre(csv_file=params['data_file'], dev=device, ctx_win_len=params['ctx_win_len'], num_time_indx=params['num_time_idx'])
'''
# Out:
# "\ndataset = electricity_pre(csv_file=params['data_file'], dev=device, ctx_win_len=params['ctx_win_len'], num_time_indx=params['num_time_idx'])\n"

# %%
num_covariates = params['num_covariates']
num_time_idx = params['num_time_idx']
num_targets = params['num_targets']
input_dim = num_time_idx + num_targets + num_covariates
'''
Size of the entire context window utilized during training
can be divided into 2 sections - first: conditioning context with input data points and network predictions conditioned on real data; 
and other one is  prediction context, where network predictions are conditioned on network output from the ealrier steps.
'''
ctx_win_len = params['ctx_win_len']
cond_win_len = params['cond_win_len']
pred_win_len = ctx_win_len - cond_win_len - 1
batch_size = params['batch_size']

# %%
model = model(num_lstms=params['num_lstms'], input_dim=input_dim, output_dim=params['num_targets'],hidden_dim=params['hidden_dim']).to(device)
optimizer = optim.Adam(model.parameters(), params['lr'])
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=params['lr_step_size'], gamma=params['lr_gamma'])

# %%
train_sampler, test_sampler = dataset.get_train_test_samplers(params['train_test_split'])
train_dataloader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, shuffle=False, num_workers=0)
test_dataloader = DataLoader(dataset, batch_size=1, sampler=test_sampler,shuffle=False, num_workers=0)
max_batches_per_epoch = params['max_batches_per_epoch']
num_epochs = params['num_epochs']

# %%
losses = []
batch_num = 1
utils = utils(device, params)
# Trainin loop
def train():
    for epoch in range(0, num_epochs):
        batch_num = 0
        for i, batch in enumerate(train_dataloader):
            if batch_num > max_batches_per_epoch:
                break    
            input, target, covariates = utils.split_batch(batch) #splitting batches : issue with sequence
            #conditioning window input,Prediction window , model op conditioned on previous values
            # model output for the previous step
            input_cond = input[:, 0:cond_win_len, :]
            input_cond, covariates = utils.scale(input_cond, covariates)
            optimizer.zero_grad()
            #forward pass
            out = model(input_cond, covariates, future=pred_win_len)
            out = utils.invert_scale(out, probabalistic=True)
            #rescale
            loss = model.NLL(out, target)
            #loss calc
            loss.backward()
            scheduler.step()
            optimizer.step()
            loss = loss.item()
            losses.append(loss)
            print(f"epoch:{epoch} /{num_epochs}| batch:{batch_num}:loss:{loss}")
            batch_num = batch_num + 1
    return model, losses

# %%
model, losses = train()
data='elec'# electricity dataset
date_=str(now).replace(" ", "")
model_save_ = f"{data}_epochs{params['num_epochs']}_{ date_ }"
torch.save(model.state_dict(), model_save_+".pth")
# Out:
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 0
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:0 /100| batch:0:loss:2.057579517364502
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 1
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:0 /100| batch:1:loss:2.057950735092163
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 2
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:1 /100| batch:0:loss:2.054147481918335
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 3
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:1 /100| batch:1:loss:2.047243356704712
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 4
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:2 /100| batch:0:loss:2.0498173236846924
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 5
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:2 /100| batch:1:loss:2.037733554840088
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 6
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:3 /100| batch:0:loss:2.039433717727661
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 7
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:3 /100| batch:1:loss:2.034658908843994
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 8
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:4 /100| batch:0:loss:2.0304272174835205
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 9
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:4 /100| batch:1:loss:2.030350685119629
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 10
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:5 /100| batch:0:loss:2.0260486602783203
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 11
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:5 /100| batch:1:loss:2.021608829498291
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 12
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:6 /100| batch:0:loss:2.022235870361328
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 13
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:6 /100| batch:1:loss:2.012472152709961
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 14
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:7 /100| batch:0:loss:2.0092835426330566
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 15
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:7 /100| batch:1:loss:2.0128679275512695
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 16
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:8 /100| batch:0:loss:2.0098085403442383
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 17
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:8 /100| batch:1:loss:1.999671220779419
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 18
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:9 /100| batch:0:loss:2.0003323554992676
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 19
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:9 /100| batch:1:loss:1.9968386888504028
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 20
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:10 /100| batch:0:loss:1.9967563152313232
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 21
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:10 /100| batch:1:loss:1.98809814453125
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 22
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:11 /100| batch:0:loss:1.9886690378189087
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 23
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:11 /100| batch:1:loss:1.984139084815979
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 24
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:12 /100| batch:0:loss:1.9848724603652954
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 25
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:12 /100| batch:1:loss:1.9758596420288086
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 26
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:13 /100| batch:0:loss:1.9741166830062866
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 27
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:13 /100| batch:1:loss:1.9746861457824707
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 28
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:14 /100| batch:0:loss:1.9695262908935547
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 29
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:14 /100| batch:1:loss:1.9673482179641724
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 30
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:15 /100| batch:0:loss:1.9636526107788086
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 31
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:15 /100| batch:1:loss:1.9613871574401855
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 32
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:16 /100| batch:0:loss:1.9548448324203491
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 33
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:16 /100| batch:1:loss:1.9583446979522705
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 34
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:17 /100| batch:0:loss:1.9513990879058838
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 35
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:17 /100| batch:1:loss:1.9498282670974731
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 36
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:18 /100| batch:0:loss:1.9476877450942993
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 37
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:18 /100| batch:1:loss:1.9415035247802734
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 38
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:19 /100| batch:0:loss:1.9410847425460815
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 39
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:19 /100| batch:1:loss:1.936099648475647
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 40
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:20 /100| batch:0:loss:1.9322867393493652
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 41
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:20 /100| batch:1:loss:1.9327590465545654
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 42
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:21 /100| batch:0:loss:1.9273781776428223
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 43
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:21 /100| batch:1:loss:1.9254218339920044
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 44
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:22 /100| batch:0:loss:1.9242868423461914
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 45
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:22 /100| batch:1:loss:1.9159400463104248
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 46
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:23 /100| batch:0:loss:1.914649486541748
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 47
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:23 /100| batch:1:loss:1.9131230115890503
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 48
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:24 /100| batch:0:loss:1.9080344438552856
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 49
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:24 /100| batch:1:loss:1.9068883657455444
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 50
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:25 /100| batch:0:loss:1.9054646492004395
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 51
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:25 /100| batch:1:loss:1.896235704421997
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 52
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:26 /100| batch:0:loss:1.894757628440857
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 53
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:26 /100| batch:1:loss:1.8936514854431152
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 54
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:27 /100| batch:0:loss:1.887101411819458
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 55
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:27 /100| batch:1:loss:1.8876760005950928
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 56
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:28 /100| batch:0:loss:1.883451223373413
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 57
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:28 /100| batch:1:loss:1.8771538734436035
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 58
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:29 /100| batch:0:loss:1.871894359588623
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 59
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:29 /100| batch:1:loss:1.874411940574646
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 60
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:30 /100| batch:0:loss:1.866390347480774
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 61
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:30 /100| batch:1:loss:1.8649977445602417
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 62
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:31 /100| batch:0:loss:1.8613650798797607
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 63
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:31 /100| batch:1:loss:1.8546202182769775
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 64
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:32 /100| batch:0:loss:1.8535808324813843
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 65
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:32 /100| batch:1:loss:1.8465015888214111
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 66
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:33 /100| batch:0:loss:1.8420436382293701
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 67
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:33 /100| batch:1:loss:1.8416345119476318
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 68
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:34 /100| batch:0:loss:1.8350054025650024
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 69
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:34 /100| batch:1:loss:1.8316253423690796
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 70
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:35 /100| batch:0:loss:1.8287980556488037
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 71
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:35 /100| batch:1:loss:1.8199864625930786
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 72
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:36 /100| batch:0:loss:1.815960168838501
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 73
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:36 /100| batch:1:loss:1.8144307136535645
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 74
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:37 /100| batch:0:loss:1.806854009628296
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 75
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:37 /100| batch:1:loss:1.8043107986450195
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 76
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:38 /100| batch:0:loss:1.7987041473388672
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 77
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:38 /100| batch:1:loss:1.7921805381774902
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 78
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:39 /100| batch:0:loss:1.7867484092712402
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 79
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:39 /100| batch:1:loss:1.7831666469573975
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 80
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:40 /100| batch:0:loss:1.7764387130737305
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 81
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:40 /100| batch:1:loss:1.771154522895813
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 82
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:41 /100| batch:0:loss:1.7682371139526367
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 83
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:41 /100| batch:1:loss:1.7560992240905762
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 84
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:42 /100| batch:0:loss:1.750253438949585
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 85
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:42 /100| batch:1:loss:1.749756932258606
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 86
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:43 /100| batch:0:loss:1.7422826290130615
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 87
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:43 /100| batch:1:loss:1.7317695617675781
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 88
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:44 /100| batch:0:loss:1.726628065109253
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 89
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:44 /100| batch:1:loss:1.7202763557434082
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 90
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:45 /100| batch:0:loss:1.7125849723815918
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 91
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:45 /100| batch:1:loss:1.705406904220581
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 92
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:46 /100| batch:0:loss:1.7010048627853394
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 93
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:46 /100| batch:1:loss:1.6864025592803955
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 94
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:47 /100| batch:0:loss:1.6858103275299072
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 95
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:47 /100| batch:1:loss:1.6691346168518066
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 96
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:48 /100| batch:0:loss:1.6664965152740479
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 97
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:48 /100| batch:1:loss:1.654090404510498
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 98
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:49 /100| batch:0:loss:1.6459014415740967
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 99
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:49 /100| batch:1:loss:1.6381173133850098
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 100
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:50 /100| batch:0:loss:1.6290206909179688
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 101
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:50 /100| batch:1:loss:1.615839958190918
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 102
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:51 /100| batch:0:loss:1.603652000427246
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 103
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:51 /100| batch:1:loss:1.5997254848480225
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 104
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:52 /100| batch:0:loss:1.5829342603683472
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 105
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:52 /100| batch:1:loss:1.5760120153427124
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 106
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:53 /100| batch:0:loss:1.559110403060913
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 107
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:53 /100| batch:1:loss:1.5525336265563965
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 108
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:54 /100| batch:0:loss:1.535003423690796
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 109
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:54 /100| batch:1:loss:1.5260590314865112
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 110
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:55 /100| batch:0:loss:1.510613203048706
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 111
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:55 /100| batch:1:loss:1.496077060699463
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 112
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:56 /100| batch:0:loss:1.4823365211486816
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 113
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:56 /100| batch:1:loss:1.4666213989257812
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 114
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:57 /100| batch:0:loss:1.4573898315429688
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 115
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:57 /100| batch:1:loss:1.429478406906128
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 116
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:58 /100| batch:0:loss:1.4150745868682861
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 117
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:58 /100| batch:1:loss:1.4066447019577026
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 118
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:59 /100| batch:0:loss:1.3763198852539062
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 119
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:59 /100| batch:1:loss:1.3759214878082275
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 120
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:60 /100| batch:0:loss:1.3403141498565674
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 121
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:60 /100| batch:1:loss:1.338510274887085
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 122
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:61 /100| batch:0:loss:1.3134021759033203
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 123
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:61 /100| batch:1:loss:1.2874847650527954
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 124
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:62 /100| batch:0:loss:1.2691996097564697
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 125
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:62 /100| batch:1:loss:1.2520266771316528
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 126
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:63 /100| batch:0:loss:1.2354998588562012
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 127
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:63 /100| batch:1:loss:1.2040081024169922
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 128
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:64 /100| batch:0:loss:1.1916818618774414
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 129
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:64 /100| batch:1:loss:1.1675167083740234
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 130
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:65 /100| batch:0:loss:1.1531621217727661
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 131
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:65 /100| batch:1:loss:1.1283773183822632
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 132
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:66 /100| batch:0:loss:1.096233606338501
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 133
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:66 /100| batch:1:loss:1.1095631122589111
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 134
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:67 /100| batch:0:loss:1.0660001039505005
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 135
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:67 /100| batch:1:loss:1.0629792213439941
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 136
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:68 /100| batch:0:loss:1.038041353225708
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 137
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:68 /100| batch:1:loss:1.0096244812011719
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 138
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:69 /100| batch:0:loss:0.9907656311988831
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 139
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:69 /100| batch:1:loss:0.9700149297714233
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 140
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:70 /100| batch:0:loss:0.9539655447006226
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 141
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:70 /100| batch:1:loss:0.9103601574897766
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 142
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:71 /100| batch:0:loss:0.9039577841758728
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 143
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:71 /100| batch:1:loss:0.8539925813674927
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 144
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:72 /100| batch:0:loss:0.8329858779907227
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 145
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:72 /100| batch:1:loss:0.8085658550262451
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 146
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:73 /100| batch:0:loss:0.7830938100814819
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 147
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:73 /100| batch:1:loss:0.730567455291748
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 148
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:74 /100| batch:0:loss:0.6897280812263489
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 149
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:74 /100| batch:1:loss:0.6894717812538147
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 150
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:75 /100| batch:0:loss:0.629523754119873
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 151
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:75 /100| batch:1:loss:0.6045291423797607
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 152
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:76 /100| batch:0:loss:0.5788216590881348
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 153
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:76 /100| batch:1:loss:0.5098633170127869
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 154
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:77 /100| batch:0:loss:0.5047367215156555
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 155
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:77 /100| batch:1:loss:0.4409601092338562
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 156
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:78 /100| batch:0:loss:0.42448222637176514
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 157
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:78 /100| batch:1:loss:0.39016270637512207
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 158
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:79 /100| batch:0:loss:0.37168818712234497
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 159
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:79 /100| batch:1:loss:0.32452571392059326
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 160
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:80 /100| batch:0:loss:0.28736722469329834
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 161
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:80 /100| batch:1:loss:0.30254870653152466
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 162
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:81 /100| batch:0:loss:0.22715288400650024
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 163
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:81 /100| batch:1:loss:0.2651270627975464
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 164
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:82 /100| batch:0:loss:0.2080516815185547
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 165
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:82 /100| batch:1:loss:0.18027538061141968
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 166
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:83 /100| batch:0:loss:0.18086707592010498
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 167
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:83 /100| batch:1:loss:0.09752863645553589
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 168
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:84 /100| batch:0:loss:0.08011174201965332
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 169
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:84 /100| batch:1:loss:0.09444057941436768
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 170
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:85 /100| batch:0:loss:0.04181593656539917
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 171
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:85 /100| batch:1:loss:0.04038876295089722
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 172
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:86 /100| batch:0:loss:-0.0034177303314208984
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 173
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:86 /100| batch:1:loss:-0.017489910125732422
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 174
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:87 /100| batch:0:loss:-0.06751811504364014
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 175
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:87 /100| batch:1:loss:-0.020068049430847168
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 176
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:88 /100| batch:0:loss:-0.05115973949432373
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 177
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:88 /100| batch:1:loss:-0.0940701961517334
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 178
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:89 /100| batch:0:loss:-0.1252225637435913
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 179
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:89 /100| batch:1:loss:-0.08005976676940918
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 180
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:90 /100| batch:0:loss:-0.11306118965148926
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 181
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:90 /100| batch:1:loss:-0.12510237097740173
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 182
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:91 /100| batch:0:loss:-0.1308041214942932
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 183
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:91 /100| batch:1:loss:-0.13970640301704407
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 184
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:92 /100| batch:0:loss:-0.1633068323135376
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 185
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:92 /100| batch:1:loss:-0.17595985531806946
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 186
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:93 /100| batch:0:loss:-0.1841406524181366
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 187
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:93 /100| batch:1:loss:-0.19608089327812195
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 188
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:94 /100| batch:0:loss:-0.22246772050857544
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 189
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:94 /100| batch:1:loss:-0.23783722519874573
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 190
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:95 /100| batch:0:loss:-0.24784743785858154
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 191
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:95 /100| batch:1:loss:-0.26713812351226807
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 192
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:96 /100| batch:0:loss:-0.2808806896209717
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 193
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:96 /100| batch:1:loss:-0.3013816475868225
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 194
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:97 /100| batch:0:loss:-0.3104338049888611
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 195
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:97 /100| batch:1:loss:-0.35061225295066833
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 196
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:98 /100| batch:0:loss:-0.3649275600910187
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 197
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:98 /100| batch:1:loss:-0.3522014617919922
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 198
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# epoch:99 /100| batch:0:loss:-0.3760303854942322
# torch.Size([31, 191, 3, 2]) torch.Size([31, 191, 3])
# 199
# ........NLL.........
# squeeze torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 3]) torch.Size([31, 191, 3])
# torch.Size([31, 191, 2])
# epoch:99 /100| batch:1:loss:-0.4135870337486267

# %%
def predicts(model, num_targets=1):
    test_dataloader_iter = iter(train_dataloader)
    for i in range(0, 1):
        test_batch = next(test_dataloader_iter)
        with torch.no_grad():
            input, target, covariates = utils.split_batch(test_batch)
            input, covariates = utils.scale(input, covariates)
            pred = model(input[:, 0:cond_win_len, :], covariates, future=pred_win_len)
            pred = utils.invert_scale(pred, True)
            loss = model.NLL(pred, target)
            print("loss (prediction): {0}".format(loss))
            preds = pred[0, :, :, :].detach().cpu().numpy()
            targets = target[0, :, :].detach().cpu().numpy()

        for j in range(num_targets):
            pred = preds[:, j, 0]  
            std = preds[:, j, 1]  
            target = targets[:, j]
            plt.figure()
            plt.xlabel('x')
            plt.ylabel('y')
            plt.xticks()
            plt.yticks()
            plt.plot(np.arange(len(target)), target, 'r', linewidth=2.0)
            plt.plot(np.arange(cond_win_len), pred[0:cond_win_len], 'b', linewidth=2.0)
            plt.plot(np.arange(cond_win_len, cond_win_len + pred_win_len), pred[cond_win_len:], 'g' + ':',
                     linewidth=2.0)
            plt.fill_between(np.arange(len(target)), pred - std, pred + std, color='cyan', alpha=0.5)
            plt.fill_between(np.arange(len(target)), pred - 2 * std, pred + 2 * std, color='cyan', alpha=0.2)
            #plt.savefig(j)
def plot_loss(losses):
    plt.figure()
    plt.title('Loss progression')
    plt.xlabel('batch no')
    plt.ylabel('loss')
    plt.plot(np.arange(len(losses)), losses, 'g', linewidth=2.0)
    plt.show()

# %%
model
# Out:
# model(
#   (lstms): ModuleList(
#     (0): LSTMCell(3, 64)
#     (1): LSTMCell(64, 64)
#   )
#   (mean): Linear(in_features=64, out_features=3, bias=True)
#   (std): Linear(in_features=64, out_features=3, bias=True)
# )

# %%
predicts(model, num_targets)
# Out:
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 200
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# loss (prediction): -0.5048553943634033

# %%
test_dataloader_iter = iter(test_dataloader)
for i in range(0, 1):
    test_batch = next(test_dataloader_iter)
    with torch.no_grad():
        input, target, covariates = utils.split_batch(test_batch)
        input, covariates = utils.scale(input, covariates)
        pred = model(input[:, 0:cond_win_len, :], covariates, future=pred_win_len)
        pred = utils.invert_scale(pred, True)
        loss = model.NLL(pred, target)
        print("loss (prediction): {0}".format(loss))
        preds = pred[0, :, :, :].detach().cpu().numpy()
        targets = target[0, :, :].detach().cpu().numpy()
        preds[:, 2:3, 0]=np.sum(preds[:, 0:2, 0:1],axis=1)
        preds[:, 2:3, 1]=np.sum(preds[:, 0:2, 1:2],axis=1)
    for j in range(num_targets):
        pred = preds[:, j, 0]  
        std = preds[:, j, 1]  
        target = targets[:, j]
        plt.figure()

        plt.xlabel('x')
        plt.ylabel('y')
        plt.xticks()
        plt.yticks()
        plt.plot(np.arange(len(target)), target, 'r', linewidth=2.0)
        plt.plot(np.arange(cond_win_len), pred[0:cond_win_len], 'b', linewidth=2.0)
        plt.plot(np.arange(cond_win_len, cond_win_len + pred_win_len), pred[cond_win_len:], 'g' + ':',
                 linewidth=2.0)
        plt.fill_between(np.arange(len(target)), pred - std, pred + std, color='cyan', alpha=0.5)
        plt.fill_between(np.arange(len(target)), pred - 2 * std, pred + 2 * std, color='cyan', alpha=0.2)
# Out:
# torch.Size([32, 191, 3, 2]) torch.Size([32, 191, 3])
# 201
# ........NLL.........
# squeeze torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 3]) torch.Size([32, 191, 3])
# torch.Size([32, 191, 2])
# loss (prediction): -0.4827157258987427

# %%
np.array([1]).dtype
# Out:
# dtype('int64')

# %%
tt=GC[0][0]

# %%
tt[:, :, 0:2].shape
# Out:
# torch.Size([32, 191, 2])

# %%
If you have an image x with shape C x H x W and want to compute the average pixel intensity value per channel you could do:

avg = torch.sum(x, dim=(1,2)) / (H*W)
# Out:
#   Input In [41]
#     If you have an image x with shape C x H x W and want to compute the average pixel intensity value per channel you could do:
#        ^
# SyntaxError: invalid syntax

# %%
tt[:, :, 0:3]

# %%
tt[:, :, 1:2]

# %%
(torch.sum(tt[:, :, 0:2], axis=2)).reshape(tt[:, :, 1:2].shape)
